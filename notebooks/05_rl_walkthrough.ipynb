# %% [markdown]
# # Phase 3: Reinforcement Learning for Discount Pricing
#
# This notebook documents the Phase 3 RL solution for CME 241.
# We move from category-level DP (Phase 2) to **product-level RL** with continuous states.
#
# **Sections:**
# 1. Setup & Motivation
# 2. Product Selection & Analysis
# 3. Product-Level Recalibration (beta_m)
# 4. Environment Design
# 5. DQN Training
# 6. Results & Policy Analysis
# 7. Comparison to DP (Phase 2)
# 8. Per-Category DQN: Isolating the Deal Fatigue Effect
# 9. Limitations & Future Work
# 10. Overnight Robustness Runs (multi-seed validation)

# %% [markdown]
# ## 1. Setup & Motivation
#
# **Why product-level?** Phase 2 used category-level promotions (e.g., promote "Ice Cream" as a category).
# This is economically unrealistic — retailers promote specific products (SKUs), not abstract categories.
# More importantly, **discount addiction** (`beta_m`) operates at the product level: consumers become
# conditioned to wait for deals on a *specific brand*, not on all ice cream. Category-level aggregation
# likely washes out the memory effect, contributing to `beta_m ≈ 0` in Phase 2 calibration.
#
# **Why RL?** With product-level actions and continuous state, the state space becomes too large for
# tabular DP. A DQN agent can learn directly from environment interaction without discretization.
#
# **Preview of key findings:**
# - Product-level recalibration yields **β_m = 0.26** (Section 3) — ~260,000x larger than Phase 2's
#   category-level estimate. Discount memory IS identifiable at the product level with correct features.
# - The calibration bugs that caused β_m=0 initially (wrong memory signal, inverted recency, optimizer
#   warm-start trapping) apply to the Phase 2 calibration code too — explaining why it found β_m≈0.
# - The DQN agent learns policies where **high β_m favors no-promotion** (memory penalty outweighs
#   immediate revenue), while a **β_m sensitivity sweep** reveals the optimal tradeoff.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
from pathlib import Path

pd.set_option("display.max_columns", 20)
pd.set_option("display.width", 120)
pd.set_option("display.float_format", "{:.4f}".format)

DATA_DIR = Path("../data/processed")
assert DATA_DIR.exists(), f"Data directory not found: {DATA_DIR}"

# %%
# ── Training cache utilities ──────────────────────────────────────────────
# Expensive DQN trainings are cached to disk so re-running the notebook
# loads results instantly.  Set FORCE_RETRAIN = True to ignore the cache.

import hashlib, json as _json, pickle
from pathlib import Path

CACHE_DIR = Path("../runs/cache")
CACHE_DIR.mkdir(parents=True, exist_ok=True)
FORCE_RETRAIN = False  # flip to True to retrain from scratch


def _cache_key(prefix: str, **kwargs) -> str:
    """Deterministic cache key from prefix + sorted kwargs."""
    blob = _json.dumps(kwargs, sort_keys=True, default=str)
    h = hashlib.sha256(blob.encode()).hexdigest()[:12]
    return f"{prefix}_{h}"


def cache_load(prefix: str, **kwargs):
    """Return cached result dict or None."""
    if FORCE_RETRAIN:
        return None
    path = CACHE_DIR / f"{_cache_key(prefix, **kwargs)}.pkl"
    if path.exists():
        print(f"  ✓ cache hit: {path.name}")
        with open(path, "rb") as f:
            return pickle.load(f)
    return None


def cache_save(data: dict, prefix: str, **kwargs):
    """Persist result dict to cache."""
    path = CACHE_DIR / f"{_cache_key(prefix, **kwargs)}.pkl"
    with open(path, "wb") as f:
        pickle.dump(data, f, protocol=pickle.HIGHEST_PROTOCOL)
    print(f"  → cached: {path.name}")


print(f"Cache dir: {CACHE_DIR.resolve()}")
print(f"Force retrain: {FORCE_RETRAIN}")
# Out:
# Cache dir: /Users/eseide/Stanford/CME-241/cme241-rl-discounts/runs/cache
# Force retrain: False

# %% [markdown]
# ## 2. Product Selection & Analysis
#
# We select 3–5 products per category from the Dunnhumby dataset.
# Selection criteria:
# - **Sufficient volume**: ≥200 transactions and ≥100 unique households (statistical significance for logistic fit)
# - **Similar deal signals** within a category (creates genuine tradeoffs for the RL agent)
# - **Price diversity** (adds another decision dimension)
#
# ### 2.1 Load and merge data

# %%
txn = pd.read_parquet(DATA_DIR / "transaction_data.parquet")
prod = pd.read_parquet(DATA_DIR / "product.parquet")

# Merge product metadata onto transactions
merged = txn.merge(
    prod[["product_id", "commodity_desc", "brand", "sub_commodity_desc"]],
    on="product_id", how="left",
)

# Our 4 categories (3 from Phase 2 + Candy from NB06)
CATEGORIES = ["FLUID MILK PRODUCTS", "ICE CREAM/MILK/SHERBTS", "FROZEN PIZZA", "CANDY - PACKAGED"]
cat_data = merged[merged["commodity_desc"].isin(CATEGORIES)].copy()

# Compute unit price and discount signals (matching calibration.py logic)
cat_data["total_discount"] = (
    cat_data["retail_disc"] + cat_data["coupon_disc"] + cat_data["coupon_match_disc"]
)
cat_data["unit_price"] = cat_data["sales_value"] / cat_data["quantity"].replace(0, np.nan)
original_price = cat_data["sales_value"] - cat_data["total_discount"]
cat_data["discount_rate"] = (-cat_data["total_discount"]) / original_price.replace(0, np.nan)
cat_data["discount_rate"] = (
    cat_data["discount_rate"].replace([np.inf, -np.inf], np.nan).fillna(0.0).clip(0.0, 0.95)
)
cat_data = cat_data.dropna(subset=["unit_price"]).copy()
cat_data = cat_data[cat_data["unit_price"] > 0].copy()

print(f"Total transactions in {len(CATEGORIES)} categories: {len(cat_data):,}")
for cat in CATEGORIES:
    sub = cat_data[cat_data["commodity_desc"] == cat]
    print(f"  {cat}: {len(sub):,} txn, {sub['product_id'].nunique()} products, {sub['household_key'].nunique()} households")
# Out:
# Total transactions in 4 categories: 190,302
#   FLUID MILK PRODUCTS: 85,494 txn, 455 products, 2421 households
#   ICE CREAM/MILK/SHERBTS: 27,558 txn, 815 products, 2150 households
#   FROZEN PIZZA: 43,292 txn, 900 products, 2051 households
#   CANDY - PACKAGED: 33,958 txn, 2471 products, 2167 households

# %% [markdown]
# ### 2.2 Compute product-level deal signals
#
# We use the **positive_centered_anomaly** mode from Phase 2 calibration, but computed
# at the *product* level instead of category level:
#
# 1. Aggregate transactions to product-week level
# 2. Compute leave-one-out discount rate per product-week
# 3. Center against product baseline (median discount rate)
# 4. Clip at zero → "promotion anomaly" signal
# 5. Representative deal signal = 90th percentile of positive weeks

# %%
cat_data["week"] = cat_data["day"].astype(int) // 7

# Product-week aggregation
pw = cat_data.groupby(["product_id", "commodity_desc", "week"]).agg(
    n_txn=("basket_id", "count"),
    n_hh=("household_key", "nunique"),
    mean_discount_rate=("discount_rate", "mean"),
    median_unit_price=("unit_price", "median"),
    mean_unit_price=("unit_price", "mean"),
).reset_index()

# Product-level baseline discount rate (median across all weeks)
product_baseline = (
    pw.groupby("product_id")["mean_discount_rate"]
    .median()
    .rename("product_discount_baseline")
)
pw = pw.merge(product_baseline, on="product_id")

# Positive centered anomaly: how much above baseline is this week's discount?
pw["deal_signal"] = (pw["mean_discount_rate"] - pw["product_discount_baseline"]).clip(lower=0.0)

# Per-product summary statistics
product_stats = pw.groupby(["product_id", "commodity_desc"]).agg(
    n_product_weeks=("week", "nunique"),
    total_txn=("n_txn", "sum"),
    median_price=("median_unit_price", "median"),
    mean_deal_signal=("deal_signal", "mean"),
    promo_week_frac=("deal_signal", lambda x: (x > 1e-6).mean()),
    deal_signal_p90=("deal_signal", lambda x: np.quantile(x[x > 1e-6], 0.9) if (x > 1e-6).any() else 0.0),
).reset_index()

# Add household count
hh_counts = cat_data.groupby("product_id")["household_key"].nunique().rename("n_hh")
product_stats = product_stats.merge(hh_counts, on="product_id", how="left")

# Add brand info
brand_info = prod[["product_id", "brand", "sub_commodity_desc"]].drop_duplicates("product_id")
product_stats = product_stats.merge(brand_info, on="product_id", how="left")

# Filter: sufficient volume
MIN_TXN = 200
MIN_HH = 100
MIN_WEEKS = 50
eligible = product_stats[
    (product_stats["total_txn"] >= MIN_TXN)
    & (product_stats["n_hh"] >= MIN_HH)
    & (product_stats["n_product_weeks"] >= MIN_WEEKS)
].copy()

print(f"Eligible products (≥{MIN_TXN} txn, ≥{MIN_HH} hh, ≥{MIN_WEEKS} weeks):")
for cat in CATEGORIES:
    n = len(eligible[eligible["commodity_desc"] == cat])
    print(f"  {cat}: {n} products")
# Out:
# Eligible products (≥200 txn, ≥100 hh, ≥50 weeks):
#   FLUID MILK PRODUCTS: 24 products
#   ICE CREAM/MILK/SHERBTS: 20 products
#   FROZEN PIZZA: 50 products
#   CANDY - PACKAGED: 18 products

# %% [markdown]
# ### 2.3 Product candidates by category
#
# For each category, we display eligible products sorted by deal signal strength.
# We want products with **similar** `deal_signal_p90` values within a category
# to create genuine tradeoffs for the RL agent.

# %%
display_cols = [
    "product_id", "total_txn", "n_hh", "n_product_weeks",
    "median_price", "deal_signal_p90", "promo_week_frac",
    "brand", "sub_commodity_desc",
]

for cat in CATEGORIES:
    sub = eligible[eligible["commodity_desc"] == cat].sort_values("deal_signal_p90", ascending=False)
    print(f"\n{'='*80}")
    print(f"{cat} — {len(sub)} eligible products")
    print(f"{'='*80}")
    display(sub[display_cols].head(15).reset_index(drop=True))
# Out:
# ================================================================================
# FLUID MILK PRODUCTS — 24 eligible products
# ================================================================================
#     product_id  total_txn  n_hh  n_product_weeks  median_price  deal_signal_p90  promo_week_frac     brand  \
# 0      1035843        341   178               95        1.5900           0.3926           0.4737   Private
# 1       910439        315   145               96        1.5000           0.2863           0.4896   Private
# 2       848319        548   247               97        2.6900           0.2830           0.4639   Private
# 3      1126899       4480   481              102        2.6600           0.2802           0.5000   Private
# 4      1029743      14401  1385              102        2.6900           0.2730           0.5000   Private
# 5      1070820       4438   508              102        2.6900           0.2691           0.5000   Private
# 6      1106523       9788  1037              102        2.6400           0.2636           0.5000   Private
# 7      1058997       4095   594              101        1.5000           0.2602           0.4950   Private
# 8       983584       1800   446              102        2.4900           0.2584           0.5000   Private
# 9       936508        285   157               89        1.2500           0.2453           0.3483  National
# 10      995242      12528  1462              102        1.5000           0.2374           0.5000   Private
# 11      862349       4108   568              101        1.5000           0.2321           0.4950   Private
# 12     7409664        200   114               81        1.2500           0.2303           0.3951  National
# 13     1133018       7305  1077              101        1.5000           0.2270           0.4950   Private
# 14      983078        340   143               94        1.2900           0.2248           0.2872   Private
#
#        sub_commodity_desc
# 0      MISCELLANEOUS MILK
# 1              BUTTERMILK
# 2      MISCELLANEOUS MILK
# 3   FLUID MILK WHITE ONLY
# 4   FLUID MILK WHITE ONLY
# 5   FLUID MILK WHITE ONLY
# 6   FLUID MILK WHITE ONLY
# 7   FLUID MILK WHITE ONLY
# 8          CHOCOLATE MILK
# 9          CHOCOLATE MILK
# 10  FLUID MILK WHITE ONLY
# 11  FLUID MILK WHITE ONLY
# 12         CHOCOLATE MILK
# 13  FLUID MILK WHITE ONLY
# 14  FLUID MILK WHITE ONLY
# ================================================================================
# ICE CREAM/MILK/SHERBTS — 20 eligible products
# ================================================================================
#     product_id  total_txn  n_hh  n_product_weeks  median_price  deal_signal_p90  promo_week_frac     brand  \
# 0       907418        298   194               71        2.5900           0.6139           0.4789  National
# 1       915874        211   132               63        2.5900           0.6139           0.4762  National
# 2      1050968        266   158               76        1.9900           0.4975           0.3289   Private
# 3      1080155        202   138               73        1.9900           0.4975           0.2603   Private
# 4       827683        584   270               95        1.9900           0.4975           0.3158   Private
# 5       988693        661   327               98        1.9900           0.4750           0.4286   Private
# 6       854042        297   204               89        2.5000           0.4509           0.4270   Private
# 7      1042942        308   149               93        4.1900           0.3010           0.3226   Private
# 8      7168026        336   171               91        4.9900           0.2942           0.4945  National
# 9      7166861        263   132               82        4.4900           0.2655           0.5000  National
# 10     1118033        304   182               86        2.5000           0.2083           0.2907   Private
# 11      962671        201   142               77        2.5000           0.2080           0.2727   Private
# 12     1096635        379   232               92        2.5000           0.1667           0.3152   Private
# 13     6463717        235   140               84        2.9900           0.1023           0.4286   Private
# 14     6463775        277   147               89        2.9900           0.1023           0.4045   Private
#
#    sub_commodity_desc
# 0       PREMIUM PINTS
# 1       PREMIUM PINTS
# 2         TRADITIONAL
# 3         TRADITIONAL
# 4         TRADITIONAL
# 5         TRADITIONAL
# 6         TRADITIONAL
# 7               PAILS
# 8             PREMIUM
# 9             PREMIUM
# 10        TRADITIONAL
# 11        TRADITIONAL
# 12        TRADITIONAL
# 13            PREMIUM
# 14            PREMIUM
# ================================================================================
# FROZEN PIZZA — 50 eligible products
# ================================================================================
#     product_id  total_txn  n_hh  n_product_weeks  median_price  deal_signal_p90  promo_week_frac     brand  \
# 0      1123720        292   174               79        1.9900           0.5252           0.4430  National
# 1       913490        423   192               98        1.0000           0.4413           0.1633  National
# 2       911502        311   163               93        1.0000           0.4413           0.1505  National
# 3       838602        423   223               92        1.0000           0.4413           0.1630  National
# 4      1127624        812   338              102        1.0000           0.4413           0.1961  National
# 5      1083721        466   245               97        1.0000           0.4413           0.1753  National
# 6       935284        650   294               97        1.0000           0.4413           0.1753  National
# 7       870211        232   136               86        1.0000           0.4413           0.1279  National
# 8       925626        906   388              100        1.0000           0.4413           0.1800  National
# 9       879152        300   174               89        1.0000           0.4413           0.1685  National
# 10      829291        291   152               86        8.1900           0.3907           0.2093  National
# 11      944139        652   271               97        2.5000           0.3171           0.3918  National
# 12      837644        242   108               91        2.9900           0.3040           0.3516  National
# 13    12648296        347   162               72        3.3388           0.2930           0.5000  National
# 14     1089025        221   133               77        3.3400           0.2927           0.4935  National
#
#    sub_commodity_desc
# 0   SNACKS/APPETIZERS
# 1       PIZZA/ECONOMY
# 2       PIZZA/ECONOMY
# 3       PIZZA/ECONOMY
# 4       PIZZA/ECONOMY
# 5       PIZZA/ECONOMY
# 6       PIZZA/ECONOMY
# 7       PIZZA/ECONOMY
# 8       PIZZA/ECONOMY
# 9       PIZZA/ECONOMY
# 10  SNACKS/APPETIZERS
# 11  PIZZA/TRADITIONAL
# 12      PIZZA/PREMIUM
# 13  PIZZA/TRADITIONAL
# 14  PIZZA/TRADITIONAL
# ================================================================================
# CANDY - PACKAGED — 18 eligible products
# ================================================================================
#     product_id  total_txn  n_hh  n_product_weeks  median_price  deal_signal_p90  promo_week_frac     brand  \
# 0      1106390        203   112               83        0.9900           0.5244           0.2892  National
# 1       950098        223   102               88        0.9900           0.4949           0.2159  National
# 2      1088634        203   117               76        0.9900           0.4949           0.4737  National
# 3      1129822        250   134               81        0.9900           0.4949           0.4074  National
# 4      7025275        239   181               54        2.9900           0.4022           0.4444  National
# 5       954966        341   215               85        2.5000           0.3584           0.3882  National
# 6     10204487        212   139               63        1.3900           0.3289           0.4603  National
# 7       903567        215   138               80        1.7900           0.2518           0.2500  National
# 8       944486        536   252              101        2.1900           0.2066           0.0792  National
# 9      9337581        916   456               99        1.0000           0.1696           0.4949  National
# 10     1008892        274   178               67        1.0000           0.1424           0.4925  National
# 11    10204822        344   231               63        1.0000           0.1418           0.4921  National
# 12     9194207        209   134               61        1.0000           0.0863           0.3443  National
# 13     9337369        355   248               77        1.0000           0.0863           0.4026  National
# 14    10204488        238   124               63        1.0000           0.0658           0.4921  National
#
#                 sub_commodity_desc
# 0                      CHEWING GUM
# 1                      CHEWING GUM
# 2                      CHEWING GUM
# 3                      CHEWING GUM
# 4            CANDY BAGS-CHOCOCLATE
# 5          CANDY BARS (MULTI PACK)
# 6          CANDY BARS (MULTI PACK)
# 7   MISCELLANEOUS CANDY (INCLUDING
# 8   MISCELLANEOUS CANDY (INCLUDING
# 9          CANDY BARS (MULTI PACK)
# 10         CANDY BARS (MULTI PACK)
# 11         CANDY BARS (MULTI PACK)
# 12         CANDY BARS (MULTI PACK)
# 13   CANDY BARS MULTI PACK W/FLOUR
# 14         CANDY BARS (MULTI PACK)

# %% [markdown]
# ### 2.4 Final product selection
#
# Selection strategy per category:
# - Pick products with deal signals in a **similar range** (within ~2x of each other)
# - Prefer products with **different prices** (creates price-quality tradeoffs)
# - Include the Phase 2 representative product where possible for continuity
# - Target 3–5 products per category

# %%
# Manual selection based on the analysis above.
# Criteria: similar deal signals within category, price diversity, sufficient volume.
#
# FLUID MILK: Products with similar deal signals (~0.21-0.27 p90)
# and a mix of price points ($1.50-$2.69)
MILK_PRODUCTS = [
    995242,   # $1.50, deal_p90=0.24, 12528 txn — Phase 2 representative
    1029743,  # $2.69, deal_p90=0.27, 14401 txn — highest volume, higher price
    908531,   # $1.50, deal_p90=0.21, 5023 txn  — chocolate milk
    862349,   # $1.50, deal_p90=0.23, 4108 txn  — white milk
    983584,   # $2.49, deal_p90=0.26, 1800 txn  — chocolate milk, higher price
]

# ICE CREAM: Products with deal signals in tight cluster (~0.45-0.50 p90)
# Traditional ice cream dominates — these are the products where
# discount addiction is most plausible.
ICE_CREAM_PRODUCTS = [
    854042,   # $2.50, deal_p90=0.45, 297 txn  — Phase 2 representative
    988693,   # $1.99, deal_p90=0.48, 661 txn  — highest volume traditional
    827683,   # $1.99, deal_p90=0.50, 584 txn  — traditional, tight cluster
    1050968,  # $1.99, deal_p90=0.50, 266 txn  — traditional, very similar signal
    1118033,  # $2.50, deal_p90=0.21, 304 txn  — traditional, lower signal (variety)
]

# FROZEN PIZZA: Products with deal signals in ~0.22-0.32 range
# Mix of sub-categories (traditional, sandwiches, snacks)
FROZEN_PIZZA_PRODUCTS = [
    907631,   # $3.49, deal_p90=0.13, 857 txn  — Phase 2 representative (lower signal)
    944139,   # $2.50, deal_p90=0.32, 652 txn  — traditional pizza
    937791,   # $2.00, deal_p90=0.22, 540 txn  — sandwiches/handhelds
    969568,   # $4.42, deal_p90=0.29, 369 txn  — traditional, highest price
    1134810,  # $2.50, deal_p90=0.27, 342 txn  — traditional, moderate
]

# CANDY - PACKAGED: Auto-select top 5 eligible products by transaction volume.
# This category has extreme deal sensitivity + fatigue (NB06: β_m=0.77, β_p=4.1)
# — the hardest RL optimization problem. Manual curation is less critical here
# because the goal is to test whether DQN learns restraint under high fatigue.
_candy_eligible = eligible[eligible["commodity_desc"] == "CANDY - PACKAGED"].copy()
_candy_eligible = _candy_eligible.sort_values("total_txn", ascending=False)
CANDY_PRODUCTS = _candy_eligible["product_id"].head(5).tolist()
assert len(CANDY_PRODUCTS) >= 3, f"Need ≥3 eligible Candy products, got {len(CANDY_PRODUCTS)}: try lowering MIN_TXN"
print(f"Auto-selected Candy products: {CANDY_PRODUCTS}")

SELECTED = {
    "FLUID MILK PRODUCTS": MILK_PRODUCTS,
    "ICE CREAM/MILK/SHERBTS": ICE_CREAM_PRODUCTS,
    "FROZEN PIZZA": FROZEN_PIZZA_PRODUCTS,
    "CANDY - PACKAGED": CANDY_PRODUCTS,
}

all_selected_ids = [pid for pids in SELECTED.values() for pid in pids]
N_PRODUCTS = len(all_selected_ids)
print(f"Total selected products: {N_PRODUCTS}")
print(f"Action space: Discrete({N_PRODUCTS + 1}) (0=no_promo, 1..{N_PRODUCTS}=promote product)")
print(f"Observation dim: 1 + {N_PRODUCTS} + {N_PRODUCTS} = {1 + 2*N_PRODUCTS} (churn + memory + recency)")
# Out:
# Auto-selected Candy products: [9337581, 10285144, 944486, 10285141, 9337369]
# Total selected products: 20
# Action space: Discrete(21) (0=no_promo, 1..20=promote product)
# Observation dim: 1 + 20 + 20 = 41 (churn + memory + recency)

# %%
# Summary table of selected products
rows = []
for cat in CATEGORIES:
    for pid in SELECTED[cat]:
        info = eligible[eligible["product_id"] == pid]
        if info.empty:
            # Product might not have passed all filters — get from full stats
            info = product_stats[product_stats["product_id"] == pid]
        if info.empty:
            rows.append({"Category": cat, "Product ID": pid, "Note": "NOT FOUND"})
            continue
        info = info.iloc[0]
        rows.append({
            "Category": cat,
            "Product ID": pid,
            "Price": f"${info['median_price']:.2f}",
            "Transactions": int(info["total_txn"]),
            "Households": int(info["n_hh"]),
            "Weeks": int(info["n_product_weeks"]),
            "Deal Signal (p90)": f"{info['deal_signal_p90']:.4f}",
            "Promo Week %": f"{info['promo_week_frac']:.1%}",
            "Sub-category": info["sub_commodity_desc"],
        })

selection_df = pd.DataFrame(rows)
display(selection_df)
# Out:
#                   Category  Product ID  Price  Transactions  Households  Weeks Deal Signal (p90) Promo Week %  \
# 0      FLUID MILK PRODUCTS      995242  $1.50         12528        1462    102            0.2374        50.0%
# 1      FLUID MILK PRODUCTS     1029743  $2.69         14401        1385    102            0.2730        50.0%
# 2      FLUID MILK PRODUCTS      908531  $1.50          5023         913    102            0.2119        50.0%
# 3      FLUID MILK PRODUCTS      862349  $1.50          4108         568    101            0.2321        49.5%
# 4      FLUID MILK PRODUCTS      983584  $2.49          1800         446    102            0.2584        50.0%
# 5   ICE CREAM/MILK/SHERBTS      854042  $2.50           297         204     89            0.4509        42.7%
# 6   ICE CREAM/MILK/SHERBTS      988693  $1.99           661         327     98            0.4750        42.9%
# 7   ICE CREAM/MILK/SHERBTS      827683  $1.99           584         270     95            0.4975        31.6%
# 8   ICE CREAM/MILK/SHERBTS     1050968  $1.99           266         158     76            0.4975        32.9%
# 9   ICE CREAM/MILK/SHERBTS     1118033  $2.50           304         182     86            0.2083        29.1%
# 10            FROZEN PIZZA      907631  $3.49           857         355    100            0.1341        50.0%
# 11            FROZEN PIZZA      944139  $2.50           652         271     97            0.3171        39.2%
# 12            FROZEN PIZZA      937791  $2.00           540         249     99            0.2199        49.5%
# 13            FROZEN PIZZA      969568  $4.42           369         190     88            0.2864        50.0%
# 14            FROZEN PIZZA     1134810  $2.50           342         161     96            0.2695        36.5%
# 15        CANDY - PACKAGED     9337581  $1.00           916         456     99            0.1696        49.5%
# 16        CANDY - PACKAGED    10285144  $1.00           611         345     80            0.0415         6.2%
# 17        CANDY - PACKAGED      944486  $2.19           536         252    101            0.2066         7.9%
# 18        CANDY - PACKAGED    10285141  $1.00           383         243     61            0.0439         3.3%
# 19        CANDY - PACKAGED     9337369  $1.00           355         248     77            0.0863        40.3%
#
#                       Sub-category
# 0            FLUID MILK WHITE ONLY
# 1            FLUID MILK WHITE ONLY
# 2                   CHOCOLATE MILK
# 3            FLUID MILK WHITE ONLY
# 4                   CHOCOLATE MILK
# 5                      TRADITIONAL
# 6                      TRADITIONAL
# 7                      TRADITIONAL
# 8                      TRADITIONAL
# 9                      TRADITIONAL
# 10               SNACKS/APPETIZERS
# 11               PIZZA/TRADITIONAL
# 12            SANDWICHES&HANDHELDS
# 13               PIZZA/TRADITIONAL
# 14               PIZZA/TRADITIONAL
# 15         CANDY BARS (MULTI PACK)
# 16         CANDY BARS (MULTI PACK)
# 17  MISCELLANEOUS CANDY (INCLUDING
# 18         CANDY BARS (MULTI PACK)
# 19   CANDY BARS MULTI PACK W/FLOUR

# %%
# Visualize: deal signal vs price for selected products
fig, axes = plt.subplots(2, 2, figsize=(14, 10))
axes = axes.flatten()
colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#9C27B0"]

for ax, cat, color in zip(axes, CATEGORIES, colors):
    cat_eligible = eligible[eligible["commodity_desc"] == cat]
    cat_selected = eligible[eligible["product_id"].isin(SELECTED[cat])]
    
    # All eligible (gray)
    ax.scatter(
        cat_eligible["median_price"], cat_eligible["deal_signal_p90"],
        alpha=0.3, color="gray", s=30, label="Eligible",
    )
    # Selected (colored)
    ax.scatter(
        cat_selected["median_price"], cat_selected["deal_signal_p90"],
        alpha=0.9, color=color, s=80, edgecolors="black", zorder=5, label="Selected",
    )
    for _, row in cat_selected.iterrows():
        ax.annotate(
            str(int(row["product_id"])),
            (row["median_price"], row["deal_signal_p90"]),
            fontsize=7, ha="left", va="bottom",
        )
    
    short_name = cat.split("/")[0].split(" - ")[0].title()
    ax.set_title(short_name, fontsize=11)
    ax.set_xlabel("Median Price ($)")
    ax.set_ylabel("Deal Signal (p90)")
    ax.legend(fontsize=8)

fig.suptitle("Selected Products: Deal Signal vs Price", fontsize=13, fontweight="bold")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Product-Level Recalibration (beta_m)
#
# Phase 2 calibrated `beta_m ≈ 0` at the **category** level. The hypothesis: category-level memory
# averages across many products within "Ice Cream", diluting the signal. Product-level memory tracks
# whether *this specific SKU* was promoted — a sharper signal more likely to reveal discount addiction.
#
# We adapt the calibration pipeline from `calibration.py`:
# 1. Build a dense household × product × week panel (replacing category with product)
# 2. Compute product-level deal signals, recency, and EWMA memory
# 3. Fit the same logistic model: `P(purchase) = σ(β₀ + β_p·deal - β_l·recency - β_m·memory)`
# 4. Search over α (memory decay) using time-based validation split
#
# ### 3.1 Build product-level panel

# %%
from discount_engine.core.calibration import fit_logistic, evaluate_nll
from tqdm.auto import tqdm

# %% [markdown]
# ### 3.2 Compute recency and memory features
#
# **Recency**: weeks since last purchase of *this specific product* by this household.
# Initialized to a **large sentinel** (52 weeks) for never-purchased products, distinguishing
# "never bought" from "just bought" (both were 0 in the initial implementation — a bug).
#
# **Memory (EWMA)**: exponentially weighted moving average of the household's **deal exposure**
# for this product. Uses `deal_signal` (ambient deal availability), NOT `hh_bought_on_deal`
# (which requires a purchase). A household that *sees* a deal but doesn't buy should still
# accumulate memory of that deal — this is the mechanism of discount addiction.

# %%
RECENCY_SENTINEL = 52.0  # 1 year — "never purchased this product"


def compute_recency(panel: pd.DataFrame) -> np.ndarray:
    """Weeks since last purchase within each household-product sequence.
    
    Uses RECENCY_SENTINEL for never-purchased products (not 0, which would
    mean 'just purchased').
    """
    recency = np.full(len(panel), RECENCY_SENTINEL, dtype=float)
    weeks = panel["week"].to_numpy(dtype=float)
    purchased = panel["purchased"].to_numpy(dtype=int)

    # Detect sequence boundaries (household-product changes)
    keys = panel[["household_key", "prod_idx"]].to_numpy()
    is_start = np.ones(len(panel), dtype=bool)
    is_start[1:] = np.any(keys[1:] != keys[:-1], axis=1)
    starts = np.flatnonzero(is_start)
    ends = np.concatenate([starts[1:], np.array([len(panel)])])

    for s, e in zip(starts, ends):
        last_purchase_time = None
        for i in range(s, e):
            if last_purchase_time is not None:
                recency[i] = max(0.0, weeks[i] - last_purchase_time)
            # else: stays at RECENCY_SENTINEL (never purchased before)
            if purchased[i]:
                last_purchase_time = weeks[i]
    return recency


def compute_memory(panel: pd.DataFrame, alpha: float) -> np.ndarray:
    """Gap-aware EWMA memory using deal_signal (ambient deal exposure).
    
    Uses deal_signal instead of hh_bought_on_deal: a household that SEES a deal
    but doesn't buy should still accumulate memory of that deal.
    """
    memory = np.zeros(len(panel), dtype=float)
    weeks = panel["week"].to_numpy(dtype=float)
    signal = panel["deal_signal"].to_numpy(dtype=float)  # ambient deal exposure

    keys = panel[["household_key", "prod_idx"]].to_numpy()
    is_start = np.ones(len(panel), dtype=bool)
    is_start[1:] = np.any(keys[1:] != keys[:-1], axis=1)
    starts = np.flatnonzero(is_start)
    ends = np.concatenate([starts[1:], np.array([len(panel)])])

    for s, e in zip(starts, ends):
        if e - s <= 1:
            continue
        prev_mem = 0.0
        prev_t = weeks[s]
        for i in range(s + 1, e):
            dt = max(0.0, weeks[i] - prev_t)
            prev_mem = (alpha ** dt) * prev_mem + max(0.0, signal[i - 1])
            memory[i] = prev_mem
            prev_t = weeks[i]
    return memory


# Compute recency
panel["recency"] = compute_recency(panel)
print(f"Recency: mean={panel['recency'].mean():.2f}, median={panel['recency'].median():.1f}, max={panel['recency'].max():.0f}")
print(f"  Never-purchased (recency={RECENCY_SENTINEL}): {(panel['recency'] == RECENCY_SENTINEL).mean():.1%}")
print(f"  Ever-purchased (recency < {RECENCY_SENTINEL}): {(panel['recency'] < RECENCY_SENTINEL).mean():.1%}")

# Quick sanity check: memory at one alpha
test_mem = compute_memory(panel, alpha=0.95)
print(f"\nMemory (α=0.95, using deal_signal): mean={test_mem.mean():.4f}, max={test_mem.max():.4f}, >0: {(test_mem > 1e-6).mean():.1%}")
# Out:
# Recency: mean=47.07, median=52.0, max=100
#   Never-purchased (recency=52.0): 85.0%
#   Ever-purchased (recency < 52.0): 13.7%
#
# Memory (α=0.95, using deal_signal): mean=0.2676, max=2.9573, >0: 83.3%

# %% [markdown]
# ### 3.3 Fit logistic model with alpha grid search
#
# We search over α ∈ {0.3, 0.5, 0.7, 0.85, 0.9, 0.95, 0.99} using a time-based
# 80/20 train/validation split. Key fixes from initial implementation:
#
# 1. **No warm-starting of β_l, β_m across alphas** — prevents boundary trapping at 0
# 2. **Feature standardization** — equalizes L-BFGS-B Hessian across deal/recency/memory
# 3. **α=0 excluded** — produces degenerate zero-memory feature with weekly data
# 4. **Start from α=0.95** (high memory) to give the optimizer a chance to find β_m > 0

# %%
# Prepare features
y = panel["purchased"].to_numpy(dtype=float)
deal = panel["deal_signal"].to_numpy(dtype=float)
recency_arr = panel["recency"].to_numpy(dtype=float)
cat_idx = panel["prod_idx"].to_numpy(dtype=int)
weeks = panel["week"].to_numpy(dtype=float)

# Time-based 80/20 split
cutoff = float(np.quantile(weeks[np.isfinite(weeks)], 0.80))
train_mask = weeks <= cutoff
val_mask = weeks > cutoff
print(f"Train: {train_mask.sum():,} rows, Val: {val_mask.sum():,} rows")
print(f"Train purchase rate: {y[train_mask].mean():.4f}, Val: {y[val_mask].mean():.4f}")

# Grid search over alpha — start from high values, exclude 0.0
# Do NOT warm-start beta_l and beta_m across alphas (prevents boundary trapping)
alpha_candidates = [0.95, 0.99, 0.90, 0.85, 0.70, 0.50, 0.30]
results = []

for alpha in tqdm(alpha_candidates, desc="Alpha grid search"):
    memory = compute_memory(panel, alpha)

    # Fresh initialization for each alpha — only warm-start intercepts
    intercepts, bp, bl, bm, _ = fit_logistic(
        y[train_mask], cat_idx[train_mask], deal[train_mask],
        recency_arr[train_mask], memory[train_mask],
        n_cats=N_PRODUCTS, initial_theta=None,
    )

    train_nll = evaluate_nll(y[train_mask], cat_idx[train_mask], deal[train_mask],
                             recency_arr[train_mask], memory[train_mask], intercepts, bp, bl, bm)
    val_nll = evaluate_nll(y[val_mask], cat_idx[val_mask], deal[val_mask],
                           recency_arr[val_mask], memory[val_mask], intercepts, bp, bl, bm)

    results.append({
        "alpha": alpha, "beta_p": bp, "beta_l": bl, "beta_m": bm,
        "train_nll": train_nll, "val_nll": val_nll,
        "intercepts": intercepts.copy(),
    })

results_df = pd.DataFrame([{k: v for k, v in r.items() if k != "intercepts"} for r in results])
print("\n" + results_df.to_string(index=False))

# %%
# Select best alpha by validation NLL
best_idx = results_df["val_nll"].idxmin()
best = results[best_idx]
best_alpha = best["alpha"]
best_bp = best["beta_p"]
best_bl = best["beta_l"]
best_bm = best["beta_m"]
best_intercepts = best["intercepts"]
best_val_nll = best["val_nll"]

print(f"Best alpha: {best_alpha}")
print(f"β_p (deal):    {best_bp:.6f}")
print(f"β_l (recency): {best_bl:.6f}")
print(f"β_m (memory):  {best_bm:.6f}")
print(f"\nComparison to Phase 2 (category-level):")
print(f"  Category β_m: 1.0e-06")
print(f"  Product  β_m: {best_bm:.6f} ({best_bm / 1e-6:.0f}x larger)" if best_bm > 1e-6 else f"  Product  β_m: {best_bm:.6f} (same order)")

# Product intercepts
print(f"\nProduct intercepts (β₀):")
for pid, idx in sorted(product_to_idx.items(), key=lambda x: x[1]):
    cat = cat_data[cat_data["product_id"] == pid]["commodity_desc"].iloc[0]
    short_cat = cat.split("/")[0][:10]
    print(f"  {pid} ({short_cat:>10}): β₀ = {best_intercepts[idx]:.4f}")
# Out:
# Best alpha: 0.99
# β_p (deal):    3.781154
# β_l (recency): 0.062320
# β_m (memory):  0.259647
#
# Comparison to Phase 2 (category-level):
#   Category β_m: 1.0e-06
#   Product  β_m: 0.259647 (259647x larger)
#
# Product intercepts (β₀):
#   995242 (FLUID MILK): β₀ = -0.3735
#   1029743 (FLUID MILK): β₀ = -0.1538
#   908531 (FLUID MILK): β₀ = -0.9494
#   862349 (FLUID MILK): β₀ = -0.7684
#   983584 (FLUID MILK): β₀ = -1.4094
#   854042 ( ICE CREAM): β₀ = -2.7486
#   988693 ( ICE CREAM): β₀ = -2.2448
#   827683 ( ICE CREAM): β₀ = -2.3823
#   1050968 ( ICE CREAM): β₀ = -3.0064
#   1118033 ( ICE CREAM): β₀ = -2.7436
#   907631 (FROZEN PIZ): β₀ = -1.9973
#   944139 (FROZEN PIZ): β₀ = -2.0577
#   937791 (FROZEN PIZ): β₀ = -2.1972
#   969568 (FROZEN PIZ): β₀ = -2.5125
#   1134810 (FROZEN PIZ): β₀ = -2.5234
#   9337581 (CANDY - PA): β₀ = -1.9726
#   10285144 (CANDY - PA): β₀ = -2.4278
#   944486 (CANDY - PA): β₀ = -2.1337
#   10285141 (CANDY - PA): β₀ = -2.7170
#   9337369 (CANDY - PA): β₀ = -2.4995

# %% [markdown]
# ### 3.4 Confounding diagnostic: is β_m genuine?
#
# The calibrated β_m = 0.26 is large enough to make promotions approximately net-neutral at the pooled level. Before accepting this, we test whether cross-product confounding inflates the estimate: products frequently on deal accumulate high memory for *all* households, and per-product intercepts may not fully absorb this.
#
# **Three diagnostics:**
# 1. **Variance decomposition** — what share of memory variance is between- vs within-product?
# 2. **Demeaned refit** — remove between-product variation from memory and recalibrate. If β_m drops, the cross-product confound was driving it.
# 3. **Placebo shuffle** — randomize memory within each product (preserving cross-sectional structure but destroying temporal sequence). If β_m survives, the signal is cross-sectional, not temporal.

# %%
# --- Confounding diagnostics for β_m ---

# 1. Variance decomposition: how much memory variance is between- vs within-product?
memory_best = compute_memory(panel, best_alpha)
panel["_mem"] = memory_best

total_var = panel["_mem"].var()
product_means = panel.groupby("prod_idx")["_mem"].transform("mean")
between_var = product_means.var()  # variance of product means
within_var = (panel["_mem"] - product_means).var()

print("=== Memory Variance Decomposition ===")
print(f"  Total variance:          {total_var:.4f}")
print(f"  Between-product variance: {between_var:.4f} ({between_var/total_var:.1%})")
print(f"  Within-product variance:  {within_var:.4f} ({within_var/total_var:.1%})")

# 2. Correlation between memory and deal_signal per product
print("\n=== Memory–Deal Correlation per Product ===")
for pid, idx in sorted(product_to_idx.items(), key=lambda x: x[1]):
    mask = panel["prod_idx"] == idx
    corr = np.corrcoef(memory_best[mask], deal[mask])[0, 1]
    cat = panel.loc[mask, "commodity_desc"].iloc[0] if "commodity_desc" in panel.columns else "?"
    print(f"  Product {pid} (idx={idx}): corr = {corr:.3f}")

# 3. Demeaned memory: remove between-product variation, refit
memory_demeaned = memory_best - product_means.to_numpy()

intercepts_d, bp_d, bl_d, bm_d, nll_d = fit_logistic(
    y[train_mask], cat_idx[train_mask], deal[train_mask],
    recency_arr[train_mask], memory_demeaned[train_mask], N_PRODUCTS,
)
nll_d_val = evaluate_nll(
    y[val_mask], cat_idx[val_mask], deal[val_mask],
    recency_arr[val_mask], memory_demeaned[val_mask],
    intercepts_d, bp_d, bl_d, bm_d,
)

print(f"\n=== Demeaned-Memory Calibration ===")
print(f"  Original β_m:  {best_bm:.6f}")
print(f"  Demeaned β_m:  {bm_d:.6f}  (Δ = {bm_d - best_bm:+.6f})")
print(f"  Original β_p:  {best_bp:.6f},  Demeaned β_p: {bp_d:.6f}")
print(f"  Original β_l:  {best_bl:.6f},  Demeaned β_l: {bl_d:.6f}")
print(f"  Val NLL: original={best_val_nll:.1f}, demeaned={nll_d_val:.1f}")

# 4. Placebo test: shuffle memory within product (breaks time structure)
np.random.seed(42)
memory_shuffled = memory_best.copy()
for idx in range(N_PRODUCTS):
    mask_idx = np.flatnonzero(panel["prod_idx"].to_numpy() == idx)
    memory_shuffled[mask_idx] = np.random.permutation(memory_shuffled[mask_idx])

intercepts_s, bp_s, bl_s, bm_s, _ = fit_logistic(
    y[train_mask], cat_idx[train_mask], deal[train_mask],
    recency_arr[train_mask], memory_shuffled[train_mask], N_PRODUCTS,
)

print(f"\n=== Placebo Test (shuffled memory within product) ===")
print(f"  Shuffled β_m: {bm_s:.6f}  (original: {best_bm:.6f})")
if abs(bm_s - best_bm) / max(best_bm, 1e-9) < 0.3:
    print("  ⚠ Memory signal survives shuffling → likely cross-sectional confound")
else:
    print("  ✓ Memory signal destroyed by shuffling → temporal structure is informative")

# Summary
print(f"\n=== Summary ===")
print(f"  Between-product share of memory variance: {between_var/total_var:.1%}")
print(f"  β_m with demeaned memory: {bm_d:.4f}")
print(f"  β_m with shuffled memory: {bm_s:.4f}")
if bm_d < best_bm * 0.5:
    print(f"  → Demeaned β_m is {bm_d/best_bm:.0%} of original: cross-product confound confirmed")
    print(f"  → Using demeaned β_m = {bm_d:.4f} for environment calibration")

# Clean up temp column
panel.drop(columns=["_mem"], inplace=True)
# Out:
# === Memory Variance Decomposition ===
#   Total variance:          0.5156
#   Between-product variance: 0.1953 (37.9%)
#   Within-product variance:  0.3203 (62.1%)
#
# === Memory–Deal Correlation per Product ===
#   Product 995242 (idx=0): corr = -0.099
#   Product 1029743 (idx=1): corr = -0.080
#   Product 908531 (idx=2): corr = -0.084
#   Product 862349 (idx=3): corr = -0.110
#   Product 983584 (idx=4): corr = -0.112
#   Product 854042 (idx=5): corr = -0.006
#   Product 988693 (idx=6): corr = -0.016
#   Product 827683 (idx=7): corr = -0.012
#   Product 1050968 (idx=8): corr = -0.010
#   Product 1118033 (idx=9): corr = 0.109
#   Product 907631 (idx=10): corr = 0.340
#   Product 944139 (idx=11): corr = -0.166
#   Product 937791 (idx=12): corr = -0.065
#   Product 969568 (idx=13): corr = 0.044
#   Product 1134810 (idx=14): corr = -0.171
#   Product 9337581 (idx=15): corr = 0.045
#   Product 10285144 (idx=16): corr = -0.027
#   Product 944486 (idx=17): corr = -0.090
#   Product 10285141 (idx=18): corr = -0.067
#   Product 9337369 (idx=19): corr = 0.073
#
# === Demeaned-Memory Calibration ===
#   Original β_m:  0.259647
#   Demeaned β_m:  0.259310  (Δ = -0.000337)
#   Original β_p:  3.781154,  Demeaned β_p: 3.781161
#   Original β_l:  0.062320,  Demeaned β_l: 0.062319
#   Val NLL: original=23294.9, demeaned=23294.8
#
# === Placebo Test (shuffled memory within product) ===
#   Shuffled β_m: 0.000000  (original: 0.259647)
#   ✓ Memory signal destroyed by shuffling → temporal structure is informative
#
# === Summary ===
#   Between-product share of memory variance: 37.9%
#   β_m with demeaned memory: 0.2593
#   β_m with shuffled memory: 0.0000

# %%
# Use demeaned β_m if confounding diagnostic confirms it's inflated
original_bm = best_bm
if bm_d < best_bm * 0.5:
    print(f"Confounding confirmed: switching from β_m={best_bm:.4f} to demeaned β_m={bm_d:.4f}")
    best_bm = bm_d
else:
    print(f"Demeaned β_m={bm_d:.4f} is similar to original β_m={best_bm:.4f} — keeping original")
# Out:
# Demeaned β_m=0.2593 is similar to original β_m=0.2596 — keeping original

# %% [markdown]
# ### 3.5 Per-category beta_m: testing for heterogeneous deal fatigue
#
# **A priori hypothesis** (stated before fitting): routine staples (milk, purchased weekly)
# should exhibit **lower** deal fatigue than discretionary indulgences (ice cream, purchased on
# impulse). Rationale: milk purchases are habitual and price-insensitive -- seeing deals should not
# erode future willingness-to-pay as strongly. Ice cream purchases are more deal-triggered, so
# repeated promotions may create stronger reference-price anchoring.
#
# **Expected ordering**: beta_m(milk) < beta_m(pizza) < beta_m(ice cream)
#
# **Method**: Fit 4 independent logistic models (one per category, 5 products each) using
# the same `fit_logistic` function with regularization scaled by `1/n` (critical: the original
# fixed L2 penalty would impose ~16x stronger effective regularization on ice cream's 1,689
# positive-class observations vs. milk's 27,780, biasing small-sample categories toward zero).
# Bootstrap 95% CIs (50 resamples, warm-started from point estimate) quantify estimation
# uncertainty. Non-overlapping CIs are suggestive of a difference, though this is not a formal
# hypothesis test.
#
# **Note on results below**: the data reverse the hypothesized ordering entirely. Milk shows
# the **highest** beta_m, and ice cream the **lowest**. A revised interpretation: high purchase
# frequency (milk is bought weekly) means more occasions on which a deal is observed, so
# discount memory accumulates faster and the deal-fatigue coefficient is larger. Infrequent
# impulse categories (ice cream) generate fewer memory-updating events, and the signal decays
# between rare purchase occasions, yielding a smaller estimated beta_m. In short, the mechanism
# is *exposure frequency*, not price sensitivity -- the more often a customer shops the
# category, the more deal history they encode. Caveat: the panel records purchases, not store
# visits, so "exposure" here means deal observation at time of purchase rather than true
# browsing exposure.

# %%
# Per-category β_m: fit 4 independent logistic models with bootstrap CIs
# Build product index ranges dynamically from SELECTED dict
offset = 0
CATEGORY_GROUPS = {}
_short_names = {
    "FLUID MILK PRODUCTS": "FLUID MILK",
    "ICE CREAM/MILK/SHERBTS": "ICE CREAM",
    "FROZEN PIZZA": "FROZEN PIZZA",
    "CANDY - PACKAGED": "CANDY",
}
for cat in CATEGORIES:
    n = len(SELECTED[cat])
    short = _short_names.get(cat, cat.split("/")[0].split(" - ")[0].upper())
    CATEGORY_GROUPS[short] = list(range(offset, offset + n))
    offset += n

# Recompute memory at best_alpha for the full panel
memory_full = compute_memory(panel, best_alpha)

N_BOOTSTRAP = 50
rng_boot = np.random.RandomState(42)

per_cat_results = {}
for cat_name, prod_indices in CATEGORY_GROUPS.items():
    # Mask: rows belonging to this category's products
    cat_mask = np.isin(cat_idx, prod_indices)

    # Remap product indices to 0..4 for this category
    local_cat_idx = np.zeros_like(cat_idx)
    for local_i, global_i in enumerate(prod_indices):
        local_cat_idx[cat_idx == global_i] = local_i

    # Subset arrays
    cat_y = y[cat_mask]
    cat_deal = deal[cat_mask]
    cat_rec = recency_arr[cat_mask]
    cat_mem = memory_full[cat_mask]
    cat_local_idx = local_cat_idx[cat_mask]
    cat_train = train_mask[cat_mask]
    cat_val = val_mask[cat_mask]

    n_prods = len(prod_indices)
    n_pos_train = cat_y[cat_train].sum()

    # Point estimate on training set
    intercepts_c, bp_c, bl_c, bm_c, train_nll_c = fit_logistic(
        cat_y[cat_train], cat_local_idx[cat_train], cat_deal[cat_train],
        cat_rec[cat_train], cat_mem[cat_train], n_prods,
    )

    # Validation NLL
    val_nll_c = evaluate_nll(
        cat_y[cat_val], cat_local_idx[cat_val], cat_deal[cat_val],
        cat_rec[cat_val], cat_mem[cat_val],
        intercepts_c, bp_c, bl_c, bm_c,
    )

    # Bootstrap CIs: resample training rows, warm-start from point estimate
    train_indices = np.where(cat_train)[0]
    warm_theta = np.concatenate([intercepts_c, [bp_c, bl_c, bm_c]])
    boot_bm = []
    boot_bp = []
    n_failed = 0
    for b in range(N_BOOTSTRAP):
        boot_idx = rng_boot.choice(train_indices, size=len(train_indices), replace=True)
        try:
            _, bp_b, _, bm_b, _ = fit_logistic(
                cat_y[boot_idx], cat_local_idx[boot_idx], cat_deal[boot_idx],
                cat_rec[boot_idx], cat_mem[boot_idx], n_prods,
                initial_theta=warm_theta, maxiter=100,
            )
            if np.isfinite(bp_b) and np.isfinite(bm_b):
                boot_bm.append(bm_b)
                boot_bp.append(bp_b)
            else:
                n_failed += 1
        except (ValueError, RuntimeError, np.linalg.LinAlgError):
            n_failed += 1

    boot_bm = np.array(boot_bm)
    boot_bp = np.array(boot_bp)
    if len(boot_bm) < 10:
        raise RuntimeError(f"Too few bootstrap resamples for {cat_name}: {len(boot_bm)}/{N_BOOTSTRAP}")
    bm_ci = (np.percentile(boot_bm, 2.5), np.percentile(boot_bm, 97.5))
    bp_ci = (np.percentile(boot_bp, 2.5), np.percentile(boot_bp, 97.5))

    per_cat_results[cat_name] = {
        "beta_m": bm_c,
        "beta_p": bp_c,
        "beta_l": bl_c,
        "val_nll": val_nll_c,
        "n_train_pos": int(n_pos_train),
        "n_train_rows": int(cat_train.sum()),
        "intercepts": intercepts_c,
        "bm_ci": bm_ci,
        "bp_ci": bp_ci,
        "boot_bm": boot_bm,
    }
    print(f"  {cat_name} done ({len(boot_bm)}/{N_BOOTSTRAP} bootstrap OK, {n_failed} failed)")

# Display results with CIs
print("\nPer-Category β_m Calibration (α = {:.2f}, reg scaled by 1/n):".format(best_alpha))
print(f"{'Category':<15} {'β_m':>8} {'95% CI':>18} {'β_p':>8} {'95% CI':>18} {'Train +':>8}")
print("-" * 82)
for cat_name, res in per_cat_results.items():
    bm_lo, bm_hi = res["bm_ci"]
    bp_lo, bp_hi = res["bp_ci"]
    print(f"{cat_name:<15} {res['beta_m']:>8.4f} [{bm_lo:>7.4f}, {bm_hi:>7.4f}] "
          f"{res['beta_p']:>8.4f} [{bp_lo:>7.4f}, {bp_hi:>7.4f}] {res['n_train_pos']:>8,}")

print(f"\n{'Pooled (all)':<15} {best_bm:>8.4f} {'':>18} {best_bp:>8.4f}")

# Check if CIs overlap — if they do, heterogeneity is not statistically significant
bm_cis = {k: v["bm_ci"] for k, v in per_cat_results.items()}

cats = list(bm_cis.keys())
all_overlap = True
for i in range(len(cats)):
    for j in range(i + 1, len(cats)):
        lo_i, hi_i = bm_cis[cats[i]]
        lo_j, hi_j = bm_cis[cats[j]]
        overlap = lo_i <= hi_j and lo_j <= hi_i
        if not overlap:
            all_overlap = False
            print(f"\n  Non-overlapping CIs: {cats[i]} vs {cats[j]}")

if all_overlap:
    print("\n  All pairwise 95% CIs overlap → no strong evidence for per-category differences")
    print("  → Pooled β_m is the appropriate estimate")
else:
    print("\n  Some CIs do not overlap → suggestive evidence for genuine heterogeneity")

# Identify lowest β_m category
min_cat = min(per_cat_results, key=lambda k: per_cat_results[k]["beta_m"])
min_bm = per_cat_results[min_cat]["beta_m"]
min_ci = per_cat_results[min_cat]["bm_ci"]
print(f"\nLowest β_m: {min_cat} at {min_bm:.4f} [{min_ci[0]:.4f}, {min_ci[1]:.4f}]")
if min_ci[1] < 0.3:
    print(f"  → Upper CI bound < 0.3: reliably in the DQN-advantaged regime")
elif min_bm < 0.3:
    print(f"  → Point estimate < 0.3 but CI includes values ≥ 0.3: uncertain regime placement")
else:
    print(f"  → Still in the convergence regime (β_m > 0.3)")

# Identify highest β_m category
max_cat = max(per_cat_results, key=lambda k: per_cat_results[k]["beta_m"])
max_bm = per_cat_results[max_cat]["beta_m"]
max_ci = per_cat_results[max_cat]["bm_ci"]
print(f"Highest β_m: {max_cat} at {max_bm:.4f} [{max_ci[0]:.4f}, {max_ci[1]:.4f}]")
if max_bm > 0.6:
    print(f"  → Deep in the fatigue regime: DQN should learn near-abstention")
# Out:
#   FLUID MILK done (50/50 bootstrap OK, 0 failed)
#   ICE CREAM done (50/50 bootstrap OK, 0 failed)
#   FROZEN PIZZA done (50/50 bootstrap OK, 0 failed)
#   CANDY done (50/50 bootstrap OK, 0 failed)
#
# Per-Category β_m Calibration (α = 0.99, reg scaled by 1/n):
# Category             β_m             95% CI      β_p             95% CI  Train +
# ----------------------------------------------------------------------------------
# FLUID MILK        0.2871 [ 0.2354,  0.3299]   4.4590 [ 4.2639,  4.6394]   27,780
# ICE CREAM         0.1064 [ 0.0283,  0.1933]   3.3663 [ 3.1161,  3.6064]    1,689
# FROZEN PIZZA      0.3200 [ 0.2618,  0.4337]   2.7944 [ 2.3652,  3.2166]    2,184
# CANDY             1.2926 [ 1.0811,  1.5835]   5.4874 [ 4.2600,  6.4238]    2,178
#
# Pooled (all)      0.2596                      3.7812
#
#   Non-overlapping CIs: FLUID MILK vs ICE CREAM
#
#   Non-overlapping CIs: FLUID MILK vs CANDY
#
#   Non-overlapping CIs: ICE CREAM vs FROZEN PIZZA
#
#   Non-overlapping CIs: ICE CREAM vs CANDY
#
#   Non-overlapping CIs: FROZEN PIZZA vs CANDY
#
#   Some CIs do not overlap → suggestive evidence for genuine heterogeneity
#
# Lowest β_m: ICE CREAM at 0.1064 [0.0283, 0.1933]
#   → Upper CI bound < 0.3: reliably in the DQN-advantaged regime
# Highest β_m: CANDY at 1.2926 [1.0811, 1.5835]
#   → Deep in the fatigue regime: DQN should learn near-abstention

# %%
# Compute per-product deal signals (representative promotion bump)
# = p90 of positive deal signals for each product, transformed through beta_p
best_memory = compute_memory(panel, best_alpha)

product_deal_signals = {}
for pid, idx in product_to_idx.items():
    mask = panel["product_id"] == pid
    pos_deals = panel.loc[mask & (panel["deal_signal"] > 1e-6), "deal_signal"]
    if len(pos_deals) > 0:
        raw_signal = float(np.quantile(pos_deals, 0.90))
    else:
        raw_signal = 0.0
    # The "logit bump" when promoting this product = beta_p * deal_signal
    logit_bump = best_bp * raw_signal
    cat = cat_data[cat_data["product_id"] == pid]["commodity_desc"].iloc[0]
    product_deal_signals[pid] = {
        "raw_deal_signal": raw_signal,
        "logit_bump": logit_bump,
        "category": cat,
        "beta_0": float(best_intercepts[idx]),
        "price": float(eligible[eligible["product_id"] == pid]["median_price"].iloc[0])
            if not eligible[eligible["product_id"] == pid].empty
            else float(product_stats[product_stats["product_id"] == pid]["median_price"].iloc[0]),
    }

# Display as table
signal_rows = []
for pid, info in product_deal_signals.items():
    signal_rows.append({
        "Product": pid,
        "Category": info["category"].split("/")[0][:15],
        "Price": f"${info['price']:.2f}",
        "Raw Deal Signal": f"{info['raw_deal_signal']:.4f}",
        "Logit Bump (β_p × signal)": f"{info['logit_bump']:.4f}",
        "β₀": f"{info['beta_0']:.4f}",
    })
display(pd.DataFrame(signal_rows))
# Out:
#      Product         Category  Price Raw Deal Signal Logit Bump (β_p × signal)       β₀
# 0     995242  FLUID MILK PROD  $1.50          0.0411                    0.1554  -0.3735
# 1    1029743  FLUID MILK PROD  $2.69          0.1634                    0.6177  -0.1538
# 2     908531  FLUID MILK PROD  $1.50          0.0195                    0.0737  -0.9494
# 3     862349  FLUID MILK PROD  $1.50          0.0719                    0.2718  -0.7684
# 4     983584  FLUID MILK PROD  $2.49          0.2203                    0.8331  -1.4094
# 5     854042        ICE CREAM  $2.50          0.3344                    1.2646  -2.7486
# 6     988693        ICE CREAM  $1.99          0.4739                    1.7918  -2.2448
# 7     827683        ICE CREAM  $1.99          0.4975                    1.8811  -2.3823
# 8    1050968        ICE CREAM  $1.99          0.4975                    1.8811  -3.0064
# 9    1118033        ICE CREAM  $2.50          0.2084                    0.7881  -2.7436
# 10    907631     FROZEN PIZZA  $3.49          0.1472                    0.5568  -1.9973
# 11    944139     FROZEN PIZZA  $2.50          0.3091                    1.1687  -2.0577
# 12    937791     FROZEN PIZZA  $2.00          0.1795                    0.6785  -2.1972
# 13    969568     FROZEN PIZZA  $4.42          0.0928                    0.3508  -2.5125
# 14   1134810     FROZEN PIZZA  $2.50          0.2716                    1.0268  -2.5234
# 15   9337581  CANDY - PACKAGE  $1.00          0.0863                    0.3264  -1.9726
# 16  10285144  CANDY - PACKAGE  $1.00          0.0499                    0.1885  -2.4278
# 17    944486  CANDY - PACKAGE  $2.19          0.2505                    0.9471  -2.1337
# 18  10285141  CANDY - PACKAGE  $1.00          0.0470                    0.1776  -2.7170
# 19   9337369  CANDY - PACKAGE  $1.00          0.0863                    0.3264  -2.4995

# %%
# Visualization: alpha selection curve
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

ax1.plot(results_df["alpha"], results_df["val_nll"], "o-", label="Validation NLL")
ax1.plot(results_df["alpha"], results_df["train_nll"], "s--", alpha=0.5, label="Train NLL")
ax1.axvline(best_alpha, color="red", linestyle=":", label=f"Best α={best_alpha}")
ax1.set_xlabel("Memory decay (α)")
ax1.set_ylabel("Negative Log-Likelihood")
ax1.set_title("Alpha Selection")
ax1.legend(fontsize=8)

ax2.plot(results_df["alpha"], results_df["beta_m"], "o-", color="purple")
ax2.axhline(1e-6, color="gray", linestyle="--", label="Category-level β_m")
ax2.set_xlabel("Memory decay (α)")
ax2.set_ylabel("β_m (memory coefficient)")
ax2.set_title("β_m vs α at Product Level")
ax2.legend(fontsize=8)
ax2.set_yscale("log") if results_df["beta_m"].max() > 0.01 else None

fig.suptitle("Product-Level Recalibration Results", fontsize=13, fontweight="bold")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 3.6 Calibration summary
#
# **Key finding: β_m = 0.26 at the product level** — ~260,000× larger than the category-level
# estimate (1e-6). The confounding diagnostics confirm this is **genuine**:
#
# - **62% within-product variance**: most memory variation is temporal, not cross-product
# - **Demeaned β_m = 0.259**: unchanged after removing between-product variation — no confound
# - **Placebo β_m = 0.000**: shuffling memory within product destroys the signal completely
#
# The per-category analysis reveals dramatic heterogeneity:
# - **Ice Cream**: β_m = 0.106 (lowest — infrequent impulse purchases accumulate less memory)
# - **Fluid Milk**: β_m = 0.287 (frequent purchases → faster memory accumulation)
# - **Frozen Pizza**: β_m = 0.320
# - **Candy**: β_m = 1.293 (highest — extreme deal fatigue despite high deal sensitivity)
#
# **Implication for the RL agent:** The β_m sensitivity sweep (Section 6.3) maps out
# three policy regimes. The per-category β_m values determine which regime each
# product category falls into — and whether the DQN can exploit category-specific
# promotion strategies.

# %% [markdown]
# ## 4. Environment Design
#
# We implement a Gymnasium-compatible environment (`DiscountEnv`) for the product-level MDP.
#
# **State** (continuous, 41-dim): `[churn_propensity, memory[20], recency[20]]`
# - `churn_propensity ∈ [0, 1]`: probability of customer churning
# - `memory[i]`: EWMA of deal exposure for product i (higher = more "addicted")
# - `recency[i]`: weeks since last purchase of product i
#
# **Actions** (discrete, 21): `{0=no_promo, 1..20=promote product i}`
# - Promoting product i sets its `raw_deal_signal` (β_p is applied in the logistic formula)
# - All other products get deal signal = 0
#
# **Dynamics** per step (one "week"):
# 1. For each product: compute `P(purchase) = σ(β₀ + β_p·deal - β_l·recency - β_m·memory)`
# 2. Sample purchase decisions independently
# 3. Compute reward: Σ_i (purchased_i × price_i × (1 - δ·promoted_i)) - churn_cost
# 4. Update state: churn (reset on purchase, +η otherwise), memory (EWMA), recency
# 5. Episode terminates if customer churns (stochastic) or max_steps reached
#
# **Critical consistency**: the deal signal fed to the logistic model is the *raw* signal,
# not the pre-multiplied `logit_bump` (= β_p × signal). Using `logit_bump` would double-count
# β_p since the formula already multiplies by β_p.
#
# ### 4.1 Environment implementation

# %%
from discount_engine.rl.env import DiscountEnv

# Instantiate environment with calibrated parameters
env_params = {
    pid: product_deal_signals[pid]
    for pid in all_selected_ids
}
env = DiscountEnv(
    product_params=env_params,
    product_order=all_selected_ids,
    beta_p=best_bp,
    beta_l=best_bl,
    beta_m=best_bm,
    alpha=best_alpha,
    delta=0.30,
    c0=0.05,
    eta=0.01,
    max_steps=200,
    recency_sentinel=RECENCY_SENTINEL,
    randomize_init=True,
)

print(f"Observation space: {env.observation_space.shape}")
print(f"Action space: {env.action_space.n} (0=no_promo, 1-{env.N}=promote)")
print(f"\nTest reset (randomized):")
obs, info = env.reset(seed=42)
print(f"  obs shape: {obs.shape}, churn={obs[0]:.3f}")
print(f"  recency range: [{obs[1+env.N:].min():.1f}, {obs[1+env.N:].max():.1f}]")
print(f"  memory range: [{obs[1:1+env.N].min():.3f}, {obs[1:1+env.N].max():.3f}]")
print(f"\nTest step (action=1, promote {all_selected_ids[0]}):")
obs, reward, term, trunc, info = env.step(1)
print(f"  reward={reward:.3f}, terminated={term}, purchases={info['purchases'].sum():.0f}")
print(f"  purchase_probs range: [{info['purchase_probs'].min():.4f}, {info['purchase_probs'].max():.4f}]")
# Out:
# Observation space: (41,)
# Action space: 21 (0=no_promo, 1-20=promote)
#
# Test reset (randomized):
#   obs shape: (41,), churn=0.243
#   recency range: [2.4, 52.0]
#   memory range: [0.000, 0.416]
#
# Test step (action=1, promote 995242):
#   reward=1.990, terminated=False, purchases=1
#   purchase_probs range: [0.0019, 0.2018]

# %% [markdown]
# ### 4.2 Environment validation
#
# We run random rollouts to verify the environment behaves sensibly:
# purchase rates, episode lengths, reward distributions.

# %%
from discount_engine.rl.rollout import run_rollout as run_rollouts

# Compare random vs no-promo baselines
random_stats = run_rollouts(env, n_episodes=500, policy="random")
no_promo_stats = run_rollouts(env, n_episodes=500, policy="no_promo")

print("Baseline comparison (500 episodes each):")
print(f"{'Metric':<25} {'Random':>12} {'No Promo':>12}")
print("-" * 50)
for label, stats in [("Random", random_stats), ("No Promo", no_promo_stats)]:
    print(f"  Mean episode reward     {stats['rewards'].mean():12.2f}")
    print(f"  Mean episode length     {stats['lengths'].mean():12.1f}")
    print(f"  Mean purchases/step     {stats['purchases_per_step'].mean():12.3f}")
    print()
# Out:
# Baseline comparison (500 episodes each):
# Metric                          Random     No Promo
# --------------------------------------------------
#   Mean episode reward            27.17
#   Mean episode length             15.3
#   Mean purchases/step            0.884
#
#   Mean episode reward            26.94
#   Mean episode length             15.2
#   Mean purchases/step            0.861

# %% [markdown]
# ## 5. DQN Training
#
# We use a standard DQN (Deep Q-Network) with:
# - **Architecture**: 2-hidden-layer MLP (128 units each, ReLU)
# - **Input**: 41-dim observation (churn + 20 memory + 20 recency)
# - **Output**: 21 Q-values (one per action)
# - **Replay buffer**: 100,000 transitions (Prioritized Experience Replay)
# - **Target network**: hard copy every 500 steps
# - **Exploration**: ε-greedy with linear decay from 1.0 → 0.05 over 20,000 steps
#
# ### 5.1 DQN Agent

# %%
import random as py_random
import torch
import torch.nn as nn
import torch.optim as optim

from discount_engine.rl.agent import DQNAgent, device
print(f"Using device: {device}")

# Build environment and agent
N_PRODUCTS = env.N
obs_dim = env.observation_space.shape[0]
n_actions = env.action_space.n

obs_scale = env.build_obs_scale()

print(f"Obs dim: {obs_dim}, Actions: {n_actions}, Products: {N_PRODUCTS}")
print(f"Env check: obs_space={env.observation_space.shape}, action_space={env.action_space.n}")

# Baselines
random_stats = run_rollouts(env, n_episodes=500, policy="random", seed=42)
no_promo_stats = run_rollouts(env, n_episodes=500, policy="no_promo", seed=42)
print(f"Baselines — Random: {random_stats['rewards'].mean():.2f}, No-promo: {no_promo_stats['rewards'].mean():.2f}")
# Out:
# Using device: cpu
# Obs dim: 41, Actions: 21, Products: 20
# Env check: obs_space=(41,), action_space=21
# Baselines — Random: 27.19, No-promo: 26.94

# %% [markdown]
# ### 5.2 Training loop

# %%
from discount_engine.rl.train import Trainer

# Train DQN (cached)
SEED = 42
TRAIN_CFG = dict(lr=3e-4, gamma=0.99, buffer_size=100_000, batch_size=128,
                 target_update_freq=500, eps_start=1.0, eps_end=0.05,
                 eps_decay_steps=20_000, hidden=128, n_episodes=5_000, seed=SEED)

cached = cache_load("pooled_dqn", **TRAIN_CFG)

if cached is not None:
    metrics = cached["metrics"]
    # Rebuild agent from cached weights
    agent = DQNAgent(
        obs_dim=obs_dim, n_actions=n_actions,
        lr=3e-4, gamma=0.99, buffer_size=100_000, batch_size=128,
        target_update_freq=500, eps_start=1.0, eps_end=0.05,
        eps_decay_steps=20_000, hidden=128, obs_scale=obs_scale,
    )
    agent.q_net.load_state_dict(cached["q_net_state"])
    agent.target_net.load_state_dict(cached["q_net_state"])
    agent.step_count = cached["step_count"]
    print(f"Loaded cached pooled DQN (seed={SEED})")
else:
    agent = DQNAgent(
        obs_dim=obs_dim, n_actions=n_actions,
        lr=3e-4, gamma=0.99, buffer_size=100_000, batch_size=128,
        target_update_freq=500, eps_start=1.0, eps_end=0.05,
        eps_decay_steps=20_000, hidden=128, obs_scale=obs_scale,
    )

    py_random.seed(SEED)
    torch.manual_seed(SEED)
    np.random.seed(SEED)

    trainer = Trainer(env, agent, seed=SEED)
    metrics = trainer.train(n_episodes=5_000, eval_interval=500, eval_episodes=200)

    cache_save({
        "metrics": metrics,
        "q_net_state": agent.q_net.state_dict(),
        "step_count": agent.step_count,
    }, "pooled_dqn", **TRAIN_CFG)

print(f"Final eval: {metrics['eval_rewards'][-1]:.2f}")
print(f"Best eval:  {metrics['eval_rewards'].max():.2f}")
print(f"Total steps: {agent.step_count:,}")
# Out:
# Training agent:   0%|          | 0/5000 [00:00<?, ?it/s]
#   → cached: pooled_dqn_99a783866812.pkl
# Final eval: 22.93
# Best eval:  23.03
# Total steps: 70,837

# %% [markdown]
# ### 5.3 Training curves

# %%
fig, axes = plt.subplots(1, 3, figsize=(16, 4))

# Panel 1: Eval reward over training
axes[0].plot(metrics["eval_points"], metrics["eval_rewards"],
             linewidth=2, color="#2ca02c", label="DQN (greedy)")
axes[0].axhline(random_stats["rewards"].mean(), color="gray", linestyle="--", alpha=0.5, label="Random baseline")
axes[0].set_xlabel("Episode")
axes[0].set_ylabel("Eval Reward (200 ep)")
axes[0].set_title("DQN Training: Eval Reward")
axes[0].legend(fontsize=7)

# Panel 2: Training loss
window = 500
if len(metrics["losses"]) > window:
    smoothed = np.convolve(metrics["losses"], np.ones(window)/window, mode="valid")
    axes[1].plot(smoothed, linewidth=0.8, color="#2ca02c")
axes[1].set_xlabel("Training Step")
axes[1].set_ylabel("Huber Loss (PER-weighted)")
axes[1].set_title("Training Loss (smoothed)")

# Panel 3: Epsilon & beta schedules
steps = np.arange(0, 60000)
eps = np.maximum(1.0 - steps / 20000 * 0.95, 0.05)
beta = np.minimum(0.4 + steps / 50000 * 0.6, 1.0)
axes[2].plot(steps, eps, label="ε (exploration)", color="#d62728")
axes[2].plot(steps, beta, label="β (IS correction)", color="#9467bd")
axes[2].set_xlabel("Step")
axes[2].set_title("Exploration & PER Schedules")
axes[2].legend(fontsize=8)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Results & Policy Analysis
#
# ### 6.1 Learned policy: action distribution
#
# What does the trained DQN prefer? We evaluate the greedy policy across many episodes
# and examine which products it chooses to promote.

# %%
# Evaluate greedy policy
def greedy_policy(obs):
    return agent.select_action(obs, greedy=True)

dqn_stats = run_rollouts(env, n_episodes=500, policy=greedy_policy, seed=99)

# Action distribution
action_labels = ["No Promo"] + [str(pid) for pid in all_selected_ids]
greedy_action_counts = np.bincount(dqn_stats["actions"], minlength=n_actions)
greedy_action_freq = greedy_action_counts / greedy_action_counts.sum()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Action frequency bar chart
colors_bar = ["gray"] + ["#1f77b4"]*5 + ["#ff7f0e"]*5 + ["#2ca02c"]*5
ax1.bar(range(n_actions), greedy_action_freq, color=colors_bar, edgecolor="black", linewidth=0.5)
ax1.set_xticks(range(n_actions))
ax1.set_xticklabels(action_labels, rotation=45, ha="right", fontsize=7)
ax1.set_ylabel("Frequency")
ax1.set_title("DQN Greedy Policy: Action Distribution")
ax1.axhline(1/n_actions, color="red", linestyle=":", alpha=0.5, label="Uniform")
ax1.legend(fontsize=8)

# Reward comparison
policies = {
    "No Promo": no_promo_stats["rewards"],
    "Random": random_stats["rewards"],
    "DQN (greedy)": dqn_stats["rewards"],
}
positions = range(len(policies))
bp = ax2.boxplot(
    [v for v in policies.values()],
    labels=list(policies.keys()),
    patch_artist=True,
)
colors_box = ["#ff9999", "#99ccff", "#99ff99"]
for patch, color in zip(bp["boxes"], colors_box):
    patch.set_facecolor(color)
ax2.set_ylabel("Episode Reward")
ax2.set_title("Policy Comparison: Episode Rewards")

plt.tight_layout()
plt.show()

# Summary stats
print("\nPolicy comparison (500 episodes):")
print(f"{'Policy':<20} {'Mean Reward':>12} {'Std':>10} {'Mean Length':>12}")
print("-" * 55)
for name, stats in [("No Promo", no_promo_stats), ("Random", random_stats), ("DQN (greedy)", dqn_stats)]:
    print(f"{name:<20} {stats['rewards'].mean():>12.2f} {stats['rewards'].std():>10.2f} {stats['lengths'].mean():>12.1f}")
# Out:
# /var/folders/gf/550wq28x3b12kj3pv8149_tr0000gn/T/ipykernel_62796/3848189518.py:31: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bp = ax2.boxplot(
# Policy comparison (500 episodes):
# Policy                Mean Reward        Std  Mean Length
# -------------------------------------------------------
# No Promo                    26.94      37.13         15.2
# Random                      27.19      37.15         15.2
# DQN (greedy)                27.12      36.37         15.5

# %% [markdown]
# ### 6.2 Policy as a function of state
#
# To understand **when** the DQN promotes vs. not, we sweep Q-values across
# different state configurations (churn propensity, recency, discount memory).
#
# **Result:** The policy is **weakly state-dependent** — it primarily promotes product
# 1050968 (ice cream, action 9) across most states, but switches to product 1134810
# (frozen pizza, action 15) in high-memory states. This is directionally sensible: ice
# cream products have the highest deal signals, and the agent avoids re-promoting them
# when memory is elevated. However, the DQN uses only 2 of 21 available actions, and
# the overall reward improvement is modest. The 5K-episode training above shows
# near-parity with baselines; extended training (80K episodes, 3 seeds — Section 10.2)
# yields DQN 26.99 ± 0.18 vs. no-promo 26.54 (+1.7%), confirming a small but consistent
# advantage. *(The baseline difference between Section 5 and 10.2 reflects different
# evaluation seeds and longer training.)*
#
# This limited differentiation reflects the difficulty of the 21-action pooled problem:
# with β_m = 0.26, the marginal value of any single promotion is small — deal fatigue
# quickly erodes the initial purchase probability boost. The sensitivity analysis in
# Section 6.3 shows the DQN achieves substantially higher rewards relative to baselines
# at lower β_m values, and the per-category experiments in Section 8 demonstrate
# clear DQN advantages when the action space is smaller (6 vs. 21 actions). The
# limited lift here is specific to the combination of a large joint action space and a
# regime where the promotion margin is thin.

# %%
# Q-value analysis: sweep churn and recency to check for state-dependent policy
def make_obs(churn, memory_vals=None, recency_vals=None):
    """Create observation vector."""
    n = env.N
    mem = np.zeros(n) if memory_vals is None else np.array(memory_vals)
    rec = np.full(n, env.recency_sentinel) if recency_vals is None else np.array(recency_vals)
    return np.concatenate([[churn], mem, rec]).astype(np.float32)


def get_q_values(obs):
    with torch.no_grad():
        normed = torch.FloatTensor(obs).unsqueeze(0).to(device) / agent.obs_scale
        return agent.q_net(normed).squeeze(0).cpu().numpy()


# --- Panel 1: Q-values vs churn at LOW recency (recently active customer) ---
churn_range = np.linspace(0.01, 0.50, 50)

# Use recency=2 for all products (recently active) and memory=0 (fresh)
q_by_churn_active = []
for c in churn_range:
    obs = make_obs(churn=c, recency_vals=np.full(env.N, 2.0))
    q_by_churn_active.append(get_q_values(obs))
q_by_churn_active = np.array(q_by_churn_active)

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Top actions by mean Q-value
top_actions = np.argsort(-q_by_churn_active.mean(axis=0))[:6]
for a_idx in top_actions:
    label = action_labels[a_idx]
    axes[0].plot(churn_range, q_by_churn_active[:, a_idx], label=label, linewidth=1.5)
axes[0].set_xlabel("Churn Propensity")
axes[0].set_ylabel("Q-value")
axes[0].set_title("Q vs Churn (active customer: recency=2, memory=0)")
axes[0].legend(fontsize=7, ncol=2)

# --- Panel 2: Q-values vs recency of best product ---
best_product_idx = int(np.argmax(env._raw_deal_signal))
recency_range = np.linspace(0, 30, 50)
q_by_recency = []
for r in recency_range:
    rec = np.full(env.N, 5.0)  # moderate recency baseline
    rec[best_product_idx] = r
    obs = make_obs(churn=0.10, recency_vals=rec)
    q_by_recency.append(get_q_values(obs))
q_by_recency = np.array(q_by_recency)

for a_idx in top_actions:
    label = action_labels[a_idx]
    axes[1].plot(recency_range, q_by_recency[:, a_idx], label=label, linewidth=1.5)
axes[1].set_xlabel(f"Recency of product {all_selected_ids[best_product_idx]}")
axes[1].set_ylabel("Q-value")
axes[1].set_title(f"Q vs Recency (churn=0.10, one product varies)")
axes[1].legend(fontsize=7, ncol=2)

# --- Panel 3: Q-values vs memory (at moderate churn) ---
memory_range = np.linspace(0, 3.0, 50)
q_by_memory = []
for m in memory_range:
    mem = np.full(env.N, m * 0.3)  # some ambient memory
    mem[best_product_idx] = m
    obs = make_obs(churn=0.15, memory_vals=mem, recency_vals=np.full(env.N, 3.0))
    q_by_memory.append(get_q_values(obs))
q_by_memory = np.array(q_by_memory)

for a_idx in top_actions:
    label = action_labels[a_idx]
    axes[2].plot(memory_range, q_by_memory[:, a_idx], label=label, linewidth=1.5)
axes[2].set_xlabel(f"Memory of product {all_selected_ids[best_product_idx]}")
axes[2].set_ylabel("Q-value")
axes[2].set_title("Q vs Memory (churn=0.15, recency=3)")
axes[2].legend(fontsize=7, ncol=2)

fig.suptitle("DQN Policy Analysis: State Dependence", fontsize=13, fontweight="bold")
plt.tight_layout()
plt.show()

# --- Policy collapse check across MULTIPLE state configurations ---
greedy_churn_active = np.argmax(q_by_churn_active, axis=1)
greedy_recency = np.argmax(q_by_recency, axis=1)
greedy_memory = np.argmax(q_by_memory, axis=1)

all_greedy = np.concatenate([greedy_churn_active, greedy_recency, greedy_memory])
n_unique_all = len(np.unique(all_greedy))

print(f"\nPolicy collapse check (across churn/recency/memory sweeps):")
print(f"  Unique actions across churn sweep (active): {len(np.unique(greedy_churn_active))}")
print(f"    Distribution: {dict(zip(*np.unique(greedy_churn_active, return_counts=True)))}")
print(f"  Unique actions across recency sweep: {len(np.unique(greedy_recency))}")
print(f"    Distribution: {dict(zip(*np.unique(greedy_recency, return_counts=True)))}")
print(f"  Unique actions across memory sweep: {len(np.unique(greedy_memory))}")
print(f"    Distribution: {dict(zip(*np.unique(greedy_memory, return_counts=True)))}")
print(f"\n  Total unique actions across all sweeps: {n_unique_all}")
if n_unique_all == 1:
    print("  ⚠ Policy collapsed to a single action")
else:
    print("  ✓ Policy is state-dependent!")
# Out:
# Policy collapse check (across churn/recency/memory sweeps):
#   Unique actions across churn sweep (active): 2
#     Distribution: {7: 14, 11: 36}
#   Unique actions across recency sweep: 1
#     Distribution: {11: 50}
#   Unique actions across memory sweep: 1
#     Distribution: {11: 50}
#
#   Total unique actions across all sweeps: 2
#   ✓ Policy is state-dependent!

# %% [markdown]
# ### 6.3 β_m sensitivity analysis
#
# Since the calibrated β_m = 0.26 makes pooled promotions approximately net-neutral (confirmed as genuine by our confounding diagnostics), we sweep β_m to map out the **policy-relevant regimes**. At each β_m, we train a fresh DQN (5,000 episodes) and compare against random and no-promotion baselines:
#
# **Three regimes emerge** (directional — single-seed point estimates; see limitations in Section 9):
#
# 1. **β_m ≈ 0 (no deal fatigue)**: Any promotion helps — DQN outperforms no-promo by +2.92 and random by +2.33. The DQN learns *which* products to promote (targeting high-signal items), yielding meaningful gains even when fatigue is absent. By β_m = 0.05, the DQN–no-promo advantage narrows to +1.08 and DQN–random to +0.67.
#
# 2. **β_m ≈ 0.1–0.2 (moderate deal fatigue)**: DQN still outperforms no-promo (+0.84 at β_m = 0.1, +0.72 at β_m = 0.2) but the margin is shrinking as memory accumulation erodes the promotion benefit.
#
# 3. **β_m ≥ 0.3 (strong deal fatigue)**: Memory cost exceeds promotion benefit. At β_m = 0.3, DQN–no-promo is only +0.11 — effectively zero. At β_m ≥ 0.7, DQN underperforms no-promo (−0.18), confirming that active promotion becomes value-destroying. Note the sweep shows some non-monotonicity (e.g., β_m = 0.5 shows +0.18 vs β_m = 0.3's +0.11), consistent with single-seed training variance.
#
# **Key insight**: the calibrated β_m = 0.26 sits at the boundary of regimes 2–3. The confounding diagnostics (Section 3.4) confirm this is not a statistical artifact — deal fatigue is genuinely this strong in weekly grocery data. The per-category analysis (Section 3.5) reveals that **ice cream** (β_m = 0.106) falls squarely in regime 2, while milk (0.287), pizza (0.320), and candy (1.293) are in regime 3. The multi-seed per-category DQN experiments (Section 8, validated in Section 10.1) confirm this prediction: ice cream shows **+84.6% ± 4.3% lift** (robust across all 5 seeds), while the other three categories show statistically zero lift.

# %%
# β_m sensitivity sweep: train DQN at different memory coefficients (cached)
beta_m_values = [0.0, 0.05, 0.1, 0.2, 0.3, 0.5, 0.7, 0.9]


def _run_one_sweep(bm_val, seed=42):
    """Train and evaluate one DQN at a given β_m, with caching."""
    sweep_cfg = dict(bm=bm_val, seed=seed, n_episodes=5000, lr=3e-4,
                     eps_decay_steps=15_000, hidden=128)
    cached = cache_load("bm_sweep", **sweep_cfg)
    if cached is not None:
        return cached

    sweep_env = DiscountEnv(
        product_params=env_params,
        product_order=all_selected_ids,
        beta_p=best_bp, beta_l=best_bl, beta_m=bm_val,
        alpha=best_alpha, delta=0.30, c0=0.05, eta=0.01,
        max_steps=200, recency_sentinel=RECENCY_SENTINEL, randomize_init=True,
    )

    sweep_obs_scale = sweep_env.build_obs_scale()
    sweep_agent = DQNAgent(
        obs_dim=obs_dim, n_actions=n_actions,
        lr=3e-4, gamma=0.99, batch_size=128,
        target_update_freq=500, eps_decay_steps=15_000, hidden=128,
        buffer_size=100_000, obs_scale=sweep_obs_scale,
    )
    py_random.seed(seed)
    torch.manual_seed(seed)
    np.random.seed(seed)

    sweep_trainer = Trainer(sweep_env, sweep_agent, seed=seed)
    sweep_metrics = sweep_trainer.train(
        n_episodes=5000, eval_interval=500, eval_episodes=200,
    )

    def _greedy(obs, _agent=sweep_agent):
        return _agent.select_action(obs, greedy=True)

    dqn_eval = run_rollouts(sweep_env, n_episodes=500, policy=_greedy, seed=99)
    random_eval = run_rollouts(sweep_env, n_episodes=500, policy="random", seed=99)
    no_promo_eval = run_rollouts(sweep_env, n_episodes=500, policy="no_promo", seed=99)

    action_dist = np.bincount(dqn_eval["actions"], minlength=n_actions)
    action_dist = action_dist / action_dist.sum()

    result = {
        "dqn_reward": dqn_eval["rewards"].mean(),
        "random_reward": random_eval["rewards"].mean(),
        "no_promo_reward": no_promo_eval["rewards"].mean(),
        "action_dist": action_dist,
        "n_unique_actions": len(action_dist.nonzero()[0]),
        "eval_curve": sweep_metrics["eval_rewards"],
        "no_promo_frac": action_dist[0],
    }

    cache_save(result, "bm_sweep", **sweep_cfg)
    return result


# Run sweep sequentially with tqdm
print(f"β_m sweep: {len(beta_m_values)} values")

sweep_results = {}
pbar = tqdm(total=len(beta_m_values), desc="β_m sweep")
for bm in beta_m_values:
    pbar.set_postfix({"β_m": f"{bm:.2f}"})
    result = _run_one_sweep(bm)
    sweep_results[bm] = result
    adv = result["dqn_reward"] - result["no_promo_reward"]
    pbar.write(f"  β_m={bm:.2f} — DQN={result['dqn_reward']:.2f}, advantage={adv:+.2f}")
    pbar.update(1)
pbar.close()

# Summary table
print(f"\nβ_m Sensitivity Summary (500 eval episodes):")
print(f"{'β_m':>8} {'DQN':>10} {'Random':>10} {'No Promo':>10} {'DQN−NoPro':>10}")
print("-" * 52)
for bm_val, res in sweep_results.items():
    dqn_r = res["dqn_reward"]
    rand_r = res["random_reward"]
    nop_r = res["no_promo_reward"]
    print(f"{bm_val:>8.3f} {dqn_r:>10.2f} {rand_r:>10.2f} {nop_r:>10.2f} {dqn_r - nop_r:>+10.2f}")
# Out:
# β_m sweep: 8 values
# β_m sweep:   0%|          | 0/8 [00:00<?, ?it/s]
# Training agent:   0%|          | 0/5000 [00:00<?, ?it/s]
#   → cached: bm_sweep_1ec8f177c317.pkl
#   β_m=0.00 — DQN=30.58, advantage=+2.92
# Training agent:   0%|          | 0/5000 [00:00<?, ?it/s]
#   → cached: bm_sweep_1afe7ed471d9.pkl
#   β_m=0.05 — DQN=28.57, advantage=+1.08
# Training agent:   0%|          | 0/5000 [00:00<?, ?it/s]
#   → cached: bm_sweep_5c1ccefa1846.pkl
#   β_m=0.10 — DQN=28.07, advantage=+0.84
# Training agent:   0%|          | 0/5000 [00:00<?, ?it/s]
#   → cached: bm_sweep_f8ce6fbefc9a.pkl
#   β_m=0.20 — DQN=27.50, advantage=+0.72
# Training agent:   0%|          | 0/5000 [00:00<?, ?it/s]
#   → cached: bm_sweep_f79dce9411e6.pkl
#   β_m=0.30 — DQN=26.58, advantage=+0.11
# Training agent:   0%|          | 0/5000 [00:00<?, ?it/s]
#   → cached: bm_sweep_b710f943fe63.pkl
#   β_m=0.50 — DQN=25.74, advantage=+0.18
# Training agent:   0%|          | 0/5000 [00:00<?, ?it/s]
#   → cached: bm_sweep_e9a7adf3e5e0.pkl
#   β_m=0.70 — DQN=24.25, advantage=-0.18
# Training agent:   0%|          | 0/5000 [00:00<?, ?it/s]
#   → cached: bm_sweep_2d91e43b0af6.pkl
#   β_m=0.90 — DQN=23.24, advantage=-0.16
#
# β_m Sensitivity Summary (500 eval episodes):
#      β_m        DQN     Random   No Promo  DQN−NoPro
# ----------------------------------------------------
#    0.000      30.58      28.38      27.66      +2.92
#    0.050      28.57      27.84      27.49      +1.08
#    0.100      28.07      27.75      27.23      +0.84
#    0.200      27.50      26.58      26.78      +0.72
#    0.300      26.58      26.18      26.47      +0.11
#    0.500      25.74      25.01      25.57      +0.18
#    0.700      24.25      23.38      24.43      -0.18
#    0.900      23.24      21.71      23.40      -0.16

# %%
# Visualize β_m sweep with baseline comparisons
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

bm_vals = list(sweep_results.keys())
dqn_rewards = [sweep_results[bm]["dqn_reward"] for bm in bm_vals]
random_rewards = [sweep_results[bm]["random_reward"] for bm in bm_vals]
no_promo_rewards = [sweep_results[bm]["no_promo_reward"] for bm in bm_vals]

# Panel 1: All three policies vs β_m
axes[0].plot(bm_vals, dqn_rewards, "o-", markersize=6, label="DQN (greedy)", color="#2ca02c")
axes[0].plot(bm_vals, random_rewards, "s--", markersize=5, label="Random", color="#1f77b4")
axes[0].plot(bm_vals, no_promo_rewards, "^:", markersize=5, label="No Promo", color="#d62728")
axes[0].set_xlabel("β_m (memory coefficient)")
axes[0].set_ylabel("Mean Episode Reward")
axes[0].set_title("Reward vs β_m (all policies)")
axes[0].legend(fontsize=8)
axes[0].grid(True, alpha=0.3)

# Panel 2: DQN advantage curve
dqn_vs_nopromo = [d - n for d, n in zip(dqn_rewards, no_promo_rewards)]
dqn_vs_random = [d - r for d, r in zip(dqn_rewards, random_rewards)]
axes[1].plot(bm_vals, dqn_vs_nopromo, "o-", markersize=7,
             label="DQN − No Promo", color="#2ca02c", linewidth=2)
axes[1].plot(bm_vals, dqn_vs_random, "s-", markersize=6, label="DQN − Random", color="#1f77b4", linewidth=1.5)
axes[1].axhline(0, color="gray", linestyle=":", alpha=0.5)

# Overlay per-category results if available
cat_colors = {"ICE CREAM": "#FF9800", "FROZEN PIZZA": "#4CAF50", "FLUID MILK": "#2196F3", "CANDY": "#9C27B0"}
if "cat_dqn_results" in dir() or "cat_dqn_results" in globals():
    for cat, res in cat_dqn_results.items():
        adv = res["dqn_reward"] - res["no_promo_reward"]
        axes[1].scatter(res["beta_m"], adv, s=120, color=cat_colors.get(cat, "black"),
                        edgecolors="black", linewidth=1.5, zorder=5)
        axes[1].annotate(cat.split()[0], (res["beta_m"], adv),
                         textcoords="offset points", xytext=(8, 5), fontsize=7, fontweight="bold")

axes[1].set_xlabel("β_m (memory coefficient)")
axes[1].set_ylabel("Reward Advantage")
axes[1].set_title("DQN Advantage vs β_m")
axes[1].legend(fontsize=8)
axes[1].grid(True, alpha=0.3)

# Panel 3: Action distributions stacked (dynamically built from CATEGORY_GROUPS)
x_pos = np.arange(len(bm_vals))
bottom = np.zeros(len(bm_vals))
_group_colors = ["gray", "#1f77b4", "#ff7f0e", "#2ca02c", "#9C27B0"]
cat_groups = [("No Promo", [0], _group_colors[0])]
for idx, (short_name, prod_indices) in enumerate(CATEGORY_GROUPS.items()):
    action_ids = [p + 1 for p in prod_indices]  # actions are 1-indexed (0 = no promo)
    cat_groups.append((short_name, action_ids, _group_colors[idx + 1]))

for group_name, action_ids, color in cat_groups:
    heights = np.array([
        sum(sweep_results[bm]["action_dist"][a] for a in action_ids if a < len(sweep_results[bm]["action_dist"]))
        for bm in bm_vals
    ])
    axes[2].bar(x_pos, heights, bottom=bottom, label=group_name, color=color, width=0.6)
    bottom += heights

axes[2].set_xticks(x_pos)
axes[2].set_xticklabels([f"{bm}" for bm in bm_vals], fontsize=8)
axes[2].set_xlabel("β_m")
axes[2].set_ylabel("Action Share")
axes[2].set_title("Category Promotion Mix vs β_m")
axes[2].legend(fontsize=7, loc="upper right")

fig.suptitle("β_m Sensitivity Analysis", fontsize=13, fontweight="bold")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7. Comparison to DP (Phase 2)
#
# Phase 2 used Value Iteration on a discretized state space with 4 actions (no-promo + 3 categories).
# Phase 3 uses DQN on a continuous state space with N_PRODUCTS+1 product-level actions.
#
# ### Key differences
#
# | Aspect | Phase 2 (DP) | Phase 3 (RL) |
# |--------|-------------|-------------|
# | **State** | Discrete (648 states) | Continuous (1 + 2×N_PRODUCTS dim) |
# | **Actions** | 4 (no promo + 3 categories) | N_PRODUCTS+1 (no promo + N_PRODUCTS products) |
# | **Algorithm** | Value Iteration (exact) | DQN (approximate) |
# | **beta_m** | ~1e-6 (category-level) | 0.26 (product-level) |
# | **Policy** | Always promote Ice Cream | Collapsed to single product (Section 6.2) |
#
# ### Methodological differences
#
# The DP and RL formulations differ in two material ways, so their reward values
# should not be compared directly:
#
# 1. **Churn dynamics.** The RL environment resets churn propensity to the baseline
#    c0 on any purchase, whereas the DP model decreases churn by eta (a gradual decay).
#    The RL reset is more aggressive at rewarding purchases -- a single purchase fully
#    restores churn to baseline, while the DP requires sustained purchasing to ratchet
#    churn down.
# 2. **Memory-bump signal.** The RL environment updates the EWMA discount memory using
#    the product-level raw deal signal (p90 of the positive-centered anomaly -- how far
#    above baseline the discount rate is during promotion weeks), while the DP model uses
#    a fixed bump delta = 0.30. These track different quantities, so the memory state
#    variable has a different interpretation across the two approaches.

# %%
import yaml

# Load Phase 2 parameters for comparison
params_path = Path("../data/processed/mdp_params.yaml")
with open(params_path) as f:
    phase2_params = yaml.safe_load(f)

print("Phase 2 (DP) vs Phase 3 (RL) — Parameter Comparison")
print("=" * 60)
comparisons = [
    ("β_p (deal)", phase2_params["beta_p"], best_bp),
    ("β_l (recency)", phase2_params["beta_l"], best_bl),
    ("β_m (memory)", phase2_params["beta_m"], best_bm),
    ("α (decay)", phase2_params["alpha"], best_alpha),
    ("η (churn rate)", phase2_params["eta"], 0.01),
    ("c0 (base churn)", phase2_params["c0"], 0.05),
    ("δ (discount)", phase2_params["delta"], 0.30),
]
print(f"{'Parameter':<20} {'Phase 2 (cat)':>15} {'Phase 3 (prod)':>15}")
print("-" * 50)
for name, v2, v3 in comparisons:
    print(f"{name:<20} {v2:>15.6f} {v3:>15.6f}")

# Phase 2 policy was "always promote Ice Cream" across all 648 states
print("\n\nPhase 2 Policy: Always promote Ice Cream (deal_signal=5.83)")
print("Phase 2 Policy Collapse: β_m ≈ 0 means memory state is irrelevant,")
print("  so the product with highest logit bump dominates everywhere.")
print(f"\nPhase 2 category deal signals:")
for cat in phase2_params["categories"]:
    print(f"  {cat['name']}: β₀={cat['beta_0']:.4f}, promotion_signal={cat.get('promotion_deal_signal', 'N/A')}")

# Phase 3 product-level deal signals are narrower
print(f"\nPhase 3 product logit bumps (β_p × raw_deal_signal):")
bumps = [(pid, info["logit_bump"]) for pid, info in product_deal_signals.items()]
bumps.sort(key=lambda x: -x[1])
for pid, bump in bumps[:5]:
    cat = product_deal_signals[pid]["category"].split("/")[0][:12]
    print(f"  {pid} ({cat}): {bump:.4f}")
print(f"  ... (range: {bumps[-1][1]:.4f} to {bumps[0][1]:.4f})")
# Out:
# Phase 2 (DP) vs Phase 3 (RL) — Parameter Comparison
# ============================================================
# Parameter              Phase 2 (cat)  Phase 3 (prod)
# --------------------------------------------------
# β_p (deal)                  0.397191        3.781154
# β_l (recency)               0.027591        0.062320
# β_m (memory)                0.000001        0.259647
# α (decay)                   0.950000        0.990000
# η (churn rate)              0.009946        0.010000
# c0 (base churn)             0.050000        0.050000
# δ (discount)                0.300000        0.300000
#
#
# Phase 2 Policy: Always promote Ice Cream (deal_signal=5.83)
# Phase 2 Policy Collapse: β_m ≈ 0 means memory state is irrelevant,
#   so the product with highest logit bump dominates everywhere.
#
# Phase 2 category deal signals:
#   FLUID MILK PRODUCTS: β₀=1.4964, promotion_signal=2.2789
#   ICE CREAM/MILK/SHERBTS: β₀=-0.8290, promotion_signal=5.8252
#   FROZEN PIZZA: β₀=-0.7362, promotion_signal=5.2508
#
# Phase 3 product logit bumps (β_p × raw_deal_signal):
#   1050968 (ICE CREAM): 1.8811
#   827683 (ICE CREAM): 1.8811
#   988693 (ICE CREAM): 1.7918
#   854042 (ICE CREAM): 1.2646
#   944139 (FROZEN PIZZA): 1.1687
#   ... (range: 0.0737 to 1.8811)

# %% [markdown]
# ## 8. Per-Category DQN: Testing the Deal Fatigue Hypothesis
#
# ### Hypothesis
#
# The β_m sensitivity sweep (Section 6.3) showed DQN outperforms baselines when β_m ≤ 0.1.
# Per-category calibration (Section 3.5) found **ice cream has β_m = 0.106** — significantly
# lower than milk (0.287), pizza (0.320), or candy (1.293), with non-overlapping 95% CIs.
#
# **Prediction**: A DQN trained on ice-cream-only should show a larger advantage over baselines
# than DQN agents trained on milk-only, pizza-only, or candy-only.
#
# ### Experimental design (pre-registered before training)
#
# To control for action-space effects, we train **four separate 5-product DQN agents**
# (one per category) with identical architecture and hyperparameters. All four environments have
# the same action space (6 actions: no-promo + 5 product promotes), controlling for problem
# dimensionality.
#
# Each category uses its own calibrated (β_p, β_l, β_m) from the per-category logistic fits,
# with product intercepts from the pooled model (consistent with the DiscountEnv design).
#
# **Important caveat**: This is not a pure β_m isolation — the categories also differ in β_p,
# β_l, product intercepts (β_0), and deal signal magnitudes. The β_m sweep (Section 6.3)
# provides the controlled experiment (varying β_m alone); the per-category results here show
# how the full parameter heterogeneity plays out in practice.

# %%
# ── Per-category DQN training (sequential with tqdm, cached) ──────────


def _train_one_category(cat_name, prod_indices, seed=42):
    """Train and evaluate DQN for one category, with caching."""
    cat_pids = [all_selected_ids[i] for i in prod_indices]
    cat_params = {pid: product_deal_signals[pid] for pid in cat_pids}
    cat_res = per_cat_results[cat_name]

    cat_cfg = dict(cat=cat_name, seed=seed, n_episodes=5000, hidden=64,
                   beta_m=float(cat_res["beta_m"]))
    cached = cache_load("percat_dqn", **cat_cfg)

    cat_env = DiscountEnv(
        product_params=cat_params, product_order=cat_pids,
        beta_p=cat_res["beta_p"], beta_l=cat_res["beta_l"], beta_m=cat_res["beta_m"],
        alpha=best_alpha, delta=0.30, c0=0.05, eta=0.01, max_steps=200,
        recency_sentinel=RECENCY_SENTINEL, randomize_init=True,
    )

    cat_obs_dim = cat_env.observation_space.shape[0]
    cat_n_actions = cat_env.action_space.n
    cat_obs_scale = cat_env.build_obs_scale()

    if cached is not None:
        # Rebuild agent from cached weights for downstream use
        cat_agent = DQNAgent(
            obs_dim=cat_obs_dim, n_actions=cat_n_actions,
            lr=3e-4, gamma=0.99, buffer_size=50_000, batch_size=128,
            target_update_freq=500, eps_start=1.0, eps_end=0.05,
            eps_decay_steps=10_000, hidden=64, obs_scale=cat_obs_scale,
        )
        cat_agent.q_net.load_state_dict(cached["q_net_state"])
        cat_agent.target_net.load_state_dict(cached["q_net_state"])
        cached["agent"] = cat_agent
        cached["env"] = cat_env
        return cached

    # Baselines
    cat_random_stats = run_rollouts(cat_env, n_episodes=500, policy="random", seed=seed)
    cat_no_promo_stats = run_rollouts(cat_env, n_episodes=500, policy="no_promo", seed=seed)

    # Train DQN
    py_random.seed(seed)
    torch.manual_seed(seed)
    np.random.seed(seed)

    cat_agent = DQNAgent(
        obs_dim=cat_obs_dim, n_actions=cat_n_actions,
        lr=3e-4, gamma=0.99, buffer_size=50_000, batch_size=128,
        target_update_freq=500, eps_start=1.0, eps_end=0.05,
        eps_decay_steps=10_000, hidden=64, obs_scale=cat_obs_scale,
    )

    cat_trainer = Trainer(cat_env, cat_agent, seed=seed)
    cat_train_results = cat_trainer.train(
        n_episodes=5_000, eval_interval=500, eval_episodes=200,
    )

    # Evaluate greedy policy
    greedy_fn = lambda obs, _agent=cat_agent: _agent.select_action(obs, greedy=True)
    greedy_stats = run_rollouts(cat_env, n_episodes=500, policy=greedy_fn, seed=seed)

    result = {
        "dqn_reward": greedy_stats["rewards"].mean(),
        "dqn_std": greedy_stats["rewards"].std(),
        "random_reward": cat_random_stats["rewards"].mean(),
        "random_std": cat_random_stats["rewards"].std(),
        "no_promo_reward": cat_no_promo_stats["rewards"].mean(),
        "no_promo_std": cat_no_promo_stats["rewards"].std(),
        "train_results": cat_train_results,
        "greedy_stats": greedy_stats,
        "agent": cat_agent,
        "env": cat_env,
        "beta_m": cat_res["beta_m"],
        "q_net_state": cat_agent.q_net.state_dict(),
    }

    # Cache everything except non-serializable agent/env
    cache_save({k: v for k, v in result.items() if k not in ("agent", "env")},
               "percat_dqn", **cat_cfg)
    return result


# Run all categories sequentially with tqdm
cat_dqn_results = {}
print(f"Per-category DQN: {len(CATEGORY_GROUPS)} categories")

pbar = tqdm(total=len(CATEGORY_GROUPS), desc="Per-category DQN")
for cat_name, prod_indices in CATEGORY_GROUPS.items():
    pbar.set_postfix({"cat": cat_name.split()[0]})
    result = _train_one_category(cat_name, prod_indices)
    cat_dqn_results[cat_name] = result
    lift = (result["dqn_reward"] - result["no_promo_reward"]) / abs(result["no_promo_reward"]) * 100
    pbar.write(f"  {cat_name} — β_m={result['beta_m']:.3f}, DQN={result['dqn_reward']:.2f}, lift={lift:+.1f}%")
    pbar.update(1)
pbar.close()

# ── Summary table ──────────────────────────────────────────────────────
print(f"\n{'='*76}")
print(f"  Per-Category DQN Results (500 eval episodes)")
print(f"{'='*76}")
print(f"{'Category':<15} {'β_m':>6} {'DQN':>10} {'Random':>10} {'No-Promo':>10} {'Lift/NP':>10}")
print("-" * 65)
for cat_name in CATEGORY_GROUPS:
    res = cat_dqn_results[cat_name]
    lift_np = (res["dqn_reward"] - res["no_promo_reward"]) / abs(res["no_promo_reward"]) * 100
    print(f"{cat_name:<15} {res['beta_m']:>6.3f} "
          f"{res['dqn_reward']:>10.2f} "
          f"{res['random_reward']:>10.2f} "
          f"{res['no_promo_reward']:>10.2f} "
          f"{lift_np:>9.1f}%")
# Out:
# Per-category DQN: 4 categories
# Per-category DQN:   0%|          | 0/4 [00:00<?, ?it/s]
# Training agent:   0%|          | 0/5000 [00:00<?, ?it/s]
#   → cached: percat_dqn_3105b7b06d74.pkl
#   FLUID MILK — β_m=0.287, DQN=15.10, lift=-0.1%
# Training agent:   0%|          | 0/5000 [00:00<?, ?it/s]
#   → cached: percat_dqn_2c3eba7ceb28.pkl
#   ICE CREAM — β_m=0.106, DQN=2.19, lift=+86.5%
# Training agent:   0%|          | 0/5000 [00:00<?, ?it/s]
#   → cached: percat_dqn_3ec26696ccc3.pkl
#   FROZEN PIZZA — β_m=0.320, DQN=1.86, lift=-3.1%
# Training agent:   0%|          | 0/5000 [00:00<?, ?it/s]
#   → cached: percat_dqn_e2f46c0b07f6.pkl
#   CANDY — β_m=1.293, DQN=0.92, lift=-1.3%
#
# ============================================================================
#   Per-Category DQN Results (500 eval episodes)
# ============================================================================
# Category           β_m        DQN     Random   No-Promo    Lift/NP
# -----------------------------------------------------------------
# FLUID MILK       0.287      15.10      14.75      15.11      -0.1%
# ICE CREAM        0.106       2.19       1.57       1.17      86.5%
# FROZEN PIZZA     0.320       1.86       1.95       1.92      -3.1%
# CANDY            1.293       0.92       0.85       0.93      -1.3%

# %%
# Per-Category DQN: Baseline vs DQN reward by category (5-seed average, fixed baseline)
import numpy as np

cat_colors = {
    "FLUID MILK": "#A0A0A0",
    "ICE CREAM": "#2E86AB",
    "FROZEN PIZZA": "#E8A838",
    "CANDY": "#808080",
}

# Fixed no-promo baselines (single evaluation)
fixed_baselines = {
    "FLUID MILK": 15.11,
    "ICE CREAM": 1.17,
    "FROZEN PIZZA": 1.92,
    "CANDY": 0.93,
}

# Per-seed DQN rewards (5 seeds: 42, 123, 456, 789, 1024)
seed_data = {
    "FLUID MILK": {"dqn": [15.10, 16.06, 14.33, 12.63, 16.19], "beta_m": 0.287},
    "ICE CREAM": {"dqn": [2.19, 2.13, 1.95, 1.84, 2.35], "beta_m": 0.106},
    "FROZEN PIZZA": {"dqn": [1.86, 1.90, 1.83, 1.74, 2.14], "beta_m": 0.320},
    "CANDY": {"dqn": [0.92, 1.02, 0.80, 0.78, 1.00], "beta_m": 1.293},
}

categories = list(seed_data.keys())
baselines = [fixed_baselines[c] for c in categories]
dqn_means = [np.mean(seed_data[c]["dqn"]) for c in categories]
dqn_ses = [np.std(seed_data[c]["dqn"], ddof=1) / np.sqrt(5) for c in categories]
betas = [seed_data[c]["beta_m"] for c in categories]
lifts = [100 * (d - b) / b for d, b in zip(dqn_means, baselines)]

x = np.arange(len(categories))
width = 0.35

fig, ax = plt.subplots(figsize=(10, 6))

# Baseline bars (no error bars — fixed single evaluation)
bars_base = ax.bar(x - width/2, baselines, width, label="No-Promotion Baseline",
                    color="#D4D4D4", edgecolor="white", linewidth=0.8)
# DQN bars with error bars across 5 seeds
bars_dqn = ax.bar(x + width/2, dqn_means, width, yerr=dqn_ses,
                   label="DQN Policy (5 seeds)",
                   color=[cat_colors[c] for c in categories],
                   edgecolor="white", linewidth=0.8, capsize=3, error_kw={"lw": 1.2})

# Annotate with lift % and β_m
for i, (cat, lift, beta) in enumerate(zip(categories, lifts, betas)):
    y_top = max(baselines[i], dqn_means[i]) + dqn_ses[i] + 0.4
    ax.text(x[i], y_top, f"{lift:+.1f}%",
            ha="center", va="bottom", fontsize=11, fontweight="bold",
            color="#2E86AB" if lift > 0 else "#C0392B")
    ax.text(x[i], -0.8, f"β_m = {beta:.3f}",
            ha="center", va="top", fontsize=9, color="#555555")

ax.set_ylabel("Mean Episode Reward (LTV)", fontsize=12)
ax.set_title("Per-Category DQN: No-Promotion Baseline vs. DQN Policy (5 seeds)",
             fontsize=13, fontweight="bold")
ax.set_xticks(x)
ax.set_xticklabels([c.title() for c in categories], fontsize=11)
ax.legend(fontsize=10, loc="upper right")
ax.grid(True, alpha=0.3, axis="y")
ax.set_ylim(-1.5, max(baselines) + 2)

plt.tight_layout()
plt.savefig("per_category_dqn.png", dpi=150, bbox_inches="tight")
plt.show()

# Print summary table
print("\n5-seed average results (fixed baseline):")
print(f"{'Category':<15} {'β_m':>6} {'DQN (mean±SE)':>16} {'Baseline':>10} {'Lift':>8}")
for i, c in enumerate(categories):
    print(f"{c:<15} {betas[i]:>6.3f} {dqn_means[i]:>7.2f} ± {dqn_ses[i]:.2f}   {baselines[i]:>8.2f} {lifts[i]:>+7.1f}%")
# Out:
# 5-seed average results (fixed baseline):
# Category           β_m    DQN (mean±SE)   Baseline     Lift
# FLUID MILK       0.287   14.86 ± 0.65      15.11    -1.6%
# ICE CREAM        0.106    2.09 ± 0.09       1.17   +78.8%
# FROZEN PIZZA     0.320    1.89 ± 0.07       1.92    -1.4%
# CANDY            1.293    0.90 ± 0.05       0.93    -2.8%

# %% [markdown]
# ### 8.1 Interpretation
#
# **Controlled comparison.** All four per-category environments use identical action spaces
# (6 actions), architecture (64-unit MLP), and training hyperparameters. The categories differ
# in their full calibrated demand parameters (β_p, β_l, β_m, per-product β_0, deal signals).
# The β_m sweep (Section 6.3) isolates the β_m effect; the per-category results here reflect
# the joint effect of all category-specific parameters. **Multi-seed robustness** (5 seeds ×
# 4 categories, Section 10.1) confirms the patterns below. *(The single-seed table above shows
# seed=42; the numbers discussed here use 5-seed averages from Section 10.1.)*
#
# **Headline result — ice cream (β_m = 0.106, β_p = 3.37).** DQN earns **+84.6% ± 4.3% SE**
# more than the no-promo baseline (mean across 5 seeds). All 5 seeds show positive lift
# (range: +67% to +95%), making this the most robust result. This category combines low deal
# fatigue with moderate deal sensitivity, and the DQN learns a genuinely valuable promotion
# strategy that the static baseline cannot match. While we cannot attribute this entirely to
# low β_m (ice cream also has favorable intercepts), the direction is consistent with the β_m
# sweep prediction.
#
# **Milk — a borderline case (β_m = 0.287).** Fluid milk shows +1.5% ± 0.6% SE lift,
# with 4 of 5 seeds positive. This is borderline significant (t ≈ 2.3, p ≈ 0.08) — suggestive
# of a weak positive effect but not conclusive. Notably, the mean DQN reward (14.86) is
# slightly *below* the single-seed no-promo baseline (15.11), reflecting the difference between
# per-seed lift ratios and the ratio of means. Milk's β_m sits right at the regime 2–3 boundary,
# consistent with near-zero expected lift.
#
# **Pizza and candy — clearly zero lift.** Frozen pizza (−0.4% ± 1.8%) and candy
# (−1.5% ± 2.2%) both show lift signs that flip across seeds, confirming these effects are
# noise around zero. This is consistent with the β_m sensitivity sweep: at β_m ≥ 0.3,
# memory accumulation means promotions provide diminishing net benefit, and the best
# policy converges to no-promo.
#
# **Candy — the "discount trap."** Candy has the highest β_p (5.49 — extreme deal sensitivity)
# *and* the highest β_m (1.293 — extreme fatigue). Consumers respond strongly to candy
# promotions in the short term, but the deal fatigue effect erases the gain. This is the most
# extreme version of the discount trap: high deal sensitivity tempts the agent to promote, but
# high fatigue punishes it. The DQN learns near-total restraint, confirming that even when
# consumers *want* deals, offering them can be value-destroying.
#
# **Contrast with the pooled model.** The 20-product DQN from Sections 5–6 exhibited policy
# collapse (selecting a single product everywhere) under its 21-action space. Decomposing into
# per-category problems with 6 actions each lets the DQN learn more effectively — though we
# note the per-category agents also use faster epsilon decay (10K vs 20K steps) and a smaller
# network (64 vs 128 units), so the comparison is not purely about action-space size.

# %% [markdown]
# ### 8.2 Aggregate LTV impact
#
# The per-category results suggest a natural deployment strategy: use the DQN policy
# for categories where it outperforms the no-promotion baseline, and default to no-promotion
# elsewhere. Using the multi-seed mean rewards (5 seeds each, Section 10.1), we estimate the
# aggregate **customer lifetime value (LTV) lift**:
#
# | Category | β_m | No-Promo LTV | DQN LTV (5-seed mean ± SE) | Optimal Policy | Strategy |
# |----------|-----|-------------|---------------------------|---------------|----------|
# | Fluid Milk | 0.287 | 15.11 | 14.86 ± 0.58 | 15.11 (no-promo) | Don't promote |
# | Ice Cream | 0.106 | 1.17 | 2.09 ± 0.08 | 2.09 (DQN) | **Promote via DQN** |
# | Frozen Pizza | 0.320 | 1.92 | 1.89 ± 0.06 | 1.92 (no-promo) | Don't promote |
# | Candy | 1.293 | 0.93 | 0.91 ± 0.05 | 0.93 (no-promo) | Don't promote |
# | **Total** | | **19.13** | | **20.05** | **+4.8% LTV** |
#
# The episode reward in our environment is the discounted sum of weekly revenues until
# customer churn — i.e., it *is* the customer LTV under that policy. The +4.8% therefore
# represents a **steady-state LTV lift**: each customer relationship generates 4.8% more
# revenue when the retailer promotes only low-fatigue categories and withholds promotions
# from high-fatigue ones.
#
# Only ice cream's DQN policy produces statistically significant lift (+84.6% ± 4.3% SE).
# The other three categories' DQN rewards are statistically indistinguishable from (or slightly
# below) their no-promo baselines, so the optimal strategy correctly defaults to no-promotion.
# The absolute DQN gain for ice cream is $0.92/customer (from 1.17 to 2.09) — modest in dollar
# terms but large relative to the category baseline, illustrating how percentage lifts amplify
# for small-baseline categories. **The entire +4.8% aggregate lift comes from a single
# low-fatigue category.**
#
# **Notably, this lift comes from only 4 of 16 available categories.** The NB06 landscape
# analysis identified additional low-fatigue categories (e.g., tropical fruit β_m = 0.18,
# bag snacks β_m = 0.09) that could yield further gains. Note that NB06 uses a different
# calibration approach (fixed α = 0.95, different product sets), so its β_m estimates are not
# directly comparable to the per-category values in Section 3.5 — but the directional ranking
# is informative. Conversely, the model's decision *not* to promote milk, pizza, and candy —
# avoiding wasted discount dollars on categories where fatigue erases the short-term benefit —
# is itself a form of value creation.
#
# **Caveats**: (1) This is simulated LTV under calibrated parameters, not A/B-tested.
# (2) The additive decomposition assumes independent per-category customer lifetimes;
# in reality, churn is shared across categories (a customer who stops buying milk likely
# also stops buying ice cream), so the +4.8% is an upper bound on the true aggregate lift.
# (3) The no-promo baselines are single-seed evaluations (seed=42, 500 episodes);
# a fully rigorous analysis would evaluate baselines across multiple seeds and report
# paired differences.

# %% [markdown]
# ## 9. Limitations & Future Work
#
# ### Limitations
#
# 1. **Deal fatigue dominates at the pooled level**: The pooled β_m = 0.26, combined with a
#    21-action exploration challenge, means the 20-product DQN cannot significantly outperform
#    simple baselines. Extended training (80K episodes, 3 seeds — Section 10.2) confirms:
#    the DQN converges to mean reward 26.99 ± 0.18 SE, essentially matching the random
#    baseline (26.99) and only marginally above no-promo (26.54). The β_m sweep suggests the
#    crossover to net-neutral occurs between β_m ≈ 0.2 and 0.3 in the 20-product setting.
#
# 2. **Per-category heterogeneity is confirmed but not fully disentangled**: Multi-seed runs
#    (5 seeds, Section 10.1) confirm ice cream's lift is robust (+84.6% ± 4.3% SE, all seeds
#    positive). However, ice cream's β_m = 0.106 differs from milk/pizza/candy not only in
#    fatigue but also in β_p, β_l, β_0, and deal signals. The β_m sweep (Section 6.3)
#    provides the cleaner isolation; per-category results reflect the joint effect of all
#    category-specific parameters.
#
# 3. **β_m sweep remains single-seed**: While the per-category and extended pooled experiments
#    now have multi-seed validation, the β_m sensitivity sweep (Section 6.3) uses a single
#    training seed. Given per-episode variance (std ≈ 39, SE of mean ≈ 1.7), several
#    sweep-point advantages are within 1 SE of zero. The "three regimes" narrative is
#    directional, not statistically confirmed at conventional significance levels.
#
# 4. **β_m sign convention**: The model forces β_m ≥ 0 (memory decreases purchase probability).
#    While this matches the "discount addiction" narrative, deal memory could also *increase*
#    purchases (brand loyalty through deals). Relaxing the sign constraint would be more
#    principled.
#
# 5. **Single-product promotion**: The action space allows promoting only one product per
#    period. Real retailers run multi-product promotions. Extending to combinatorial action
#    spaces would require action masking or factored Q-networks.
#
# 6. **Homogeneous customers**: The environment models a single representative customer.
#    Customer segmentation (different β₀ per segment) would enable personalized promotions.
#
# 7. **Demand model simplicity**: The logistic purchase model treats products as independent
#    (no cross-product substitution). Promoting one ice cream brand should reduce demand
#    for competing brands.
#
# 8. **Recency calibration note**: The environment resets recency to 1 on purchase
#    (matching the calibration model where recency = weeks since last purchase ≥ 1).
#    An earlier version reset to 0, causing a slight out-of-distribution input; this was
#    corrected during development. All results in this notebook use the corrected version.
#
# ### Future directions
#
# - **Multi-seed β_m sweep**: Extend the sensitivity sweep to 5+ seeds per β_m value to
#   produce confidence intervals. This would sharpen the "three regimes" boundary estimates
#   and the sweet-spot location.
#
# - **Promotion budget constraint**: Add `remaining_budget` to the state. Forces non-trivial
#   timing decisions even at high β_m values, where the agent must allocate limited promotions
#   to maximize long-run revenue despite deal fatigue.
#
# - **Robustness analysis**: Train with one β_m, evaluate with a different β_m. Answers:
#   "How robust is the learned policy to parameter uncertainty?"
#
# - **Cross-product substitution**: Add substitution effects so promoting product A reduces
#   demand for competing products. This creates richer strategic tradeoffs.
#
# - **Customer heterogeneity**: Segment customers by deal sensitivity. Some customers may
#   have low β_m (promotions always help) while others have high β_m (promotions cause fatigue).
#
# ### CME 241 contribution summary
#
# This project demonstrates the full MDP pipeline for discount pricing:
# 1. **Phase 1**: Problem formulation — state/action/transition/reward specification
# 2. **Phase 2**: Dynamic Programming — exact solution on discretized state space
# 3. **Phase 3**: Reinforcement Learning — DQN on continuous product-level state space,
#    recovering **β_m = 0.26** pooled (validated via confounding diagnostics) with
#    significant per-category heterogeneity (ice cream β_m = 0.106, candy β_m = 1.293)
#
# The central finding: **deal fatigue (β_m) varies by category**, and RL-based promotion
# optimization is most valuable where fatigue is low. The per-category DQN experiment
# (Section 8) demonstrates this with multi-seed robustness — same architecture, same action
# space, different calibrated parameters — showing that ice cream's low deal fatigue translates
# to **+84.6% ± 4.3% DQN lift** (5 seeds, all positive), while high-fatigue categories
# (milk, frozen pizza, candy) show statistically zero lift. The aggregate LTV impact is +4.8%,
# driven entirely by the single low-fatigue category.

# %% [markdown]
# ## 10. Overnight Robustness Runs
#
# ### 10.1 Multi-seed per-category DQN (5 seeds × 4 categories)
#
# Same architecture and hyperparameters as Section 8, but repeated across 5 seeds to quantify
# training variance. Reports mean ± SE for each category's DQN lift.

# %%
# ── Multi-seed per-category DQN (cached via _train_one_category) ─────────
# 5 seeds × 4 categories = 20 training runs
# Each run: 5K episodes (~1-2 min) → total ~30-40 min (instant if cached)

MULTI_SEEDS = [42, 123, 456, 789, 1024]
SNAPSHOT_DIR = Path("../runs/overnight")
SNAPSHOT_DIR.mkdir(parents=True, exist_ok=True)

multi_seed_results = {}  # cat_name -> list of per-seed result dicts

total_runs = len(CATEGORY_GROUPS) * len(MULTI_SEEDS)
pbar = tqdm(total=total_runs, desc="Multi-seed per-category DQN")

for cat_name, prod_indices in CATEGORY_GROUPS.items():
    cat_seed_results = []

    for seed in MULTI_SEEDS:
        pbar.set_postfix({"cat": cat_name.split()[0], "seed": seed})

        result = _train_one_category(cat_name, prod_indices, seed=seed)

        # Save model snapshot
        snapshot_path = SNAPSHOT_DIR / f"percat_{cat_name.replace(' ', '_')}_seed{seed}.pt"
        torch.save(result["agent"].q_net.state_dict(), snapshot_path)

        cat_seed_results.append({
            "seed": seed,
            "dqn_reward": result["dqn_reward"],
            "dqn_std": result["dqn_std"],
            "random_reward": result["random_reward"],
            "no_promo_reward": result["no_promo_reward"],
            "lift_pct": (result["dqn_reward"] - result["no_promo_reward"])
                        / abs(result["no_promo_reward"]) * 100,
            "best_eval": result["train_results"]["eval_rewards"].max(),
            "final_eval": result["train_results"]["eval_rewards"][-1],
        })

        pbar.update(1)

    multi_seed_results[cat_name] = cat_seed_results

pbar.close()

# ── Summary table with mean ± SE ─────────────────────────────────────────
print(f"\n{'='*90}")
print(f"  Multi-Seed Per-Category DQN Results ({len(MULTI_SEEDS)} seeds × 500 eval episodes)")
print(f"{'='*90}")
print(f"{'Category':<15} {'β_m':>6} {'DQN Mean±SE':>16} {'No-Promo':>10} "
      f"{'Lift Mean±SE':>18} {'Seeds':>8}")
print("-" * 80)

for cat_name in CATEGORY_GROUPS:
    results = multi_seed_results[cat_name]
    dqn_rewards = np.array([r["dqn_reward"] for r in results])
    lifts = np.array([r["lift_pct"] for r in results])
    no_promo = results[0]["no_promo_reward"]  # same across seeds (deterministic env reset)
    bm = per_cat_results[cat_name]["beta_m"]

    dqn_mean = dqn_rewards.mean()
    dqn_se = dqn_rewards.std() / np.sqrt(len(dqn_rewards))
    lift_mean = lifts.mean()
    lift_se = lifts.std() / np.sqrt(len(lifts))

    print(f"{cat_name:<15} {bm:>6.3f} {dqn_mean:>8.2f} ± {dqn_se:>5.2f} {no_promo:>10.2f} "
          f"{lift_mean:>+8.1f}% ± {lift_se:>5.1f}% {len(results):>8}")

# Per-seed detail
print(f"\n{'─'*70}")
print("Per-seed detail:")
for cat_name in CATEGORY_GROUPS:
    print(f"\n  {cat_name}:")
    for r in multi_seed_results[cat_name]:
        print(f"    seed={r['seed']:>5}  DQN={r['dqn_reward']:>7.2f}  "
              f"lift={r['lift_pct']:>+6.1f}%  best_eval={r['best_eval']:>7.2f}")

# Save results to JSON for later analysis
import json as _json
summary = {}
for cat_name in CATEGORY_GROUPS:
    results = multi_seed_results[cat_name]
    dqn_rewards = [r["dqn_reward"] for r in results]
    lifts = [r["lift_pct"] for r in results]
    summary[cat_name] = {
        "beta_m": float(per_cat_results[cat_name]["beta_m"]),
        "seeds": MULTI_SEEDS,
        "dqn_rewards": dqn_rewards,
        "lifts_pct": lifts,
        "no_promo_reward": float(results[0]["no_promo_reward"]),
        "dqn_mean": float(np.mean(dqn_rewards)),
        "dqn_se": float(np.std(dqn_rewards) / np.sqrt(len(dqn_rewards))),
        "lift_mean": float(np.mean(lifts)),
        "lift_se": float(np.std(lifts) / np.sqrt(len(lifts))),
    }

with open(SNAPSHOT_DIR / "multi_seed_percat_results.json", "w") as f:
    _json.dump(summary, f, indent=2)
print(f"\nResults saved to {SNAPSHOT_DIR / 'multi_seed_percat_results.json'}")

# %% [markdown]
# ### 10.2 Extended pooled DQN (3 seeds × 80K episodes)
#
# The Section 5 pooled DQN trained for only 5K episodes (71K steps) — likely insufficient
# for 21 actions. We run 3 seeds at 80K episodes (~1.1M steps each) to determine whether
# longer training changes the result. Model snapshots saved every 5K episodes for recovery.

# %%
# ── Extended pooled DQN: 3 seeds × 80K episodes with snapshots (cached) ──

POOLED_SEEDS = [42, 123, 456]
POOLED_N_EPISODES = 80_000
SNAPSHOT_INTERVAL = 5_000  # save model every 5K episodes
EVAL_INTERVAL = 2_500      # eval every 2.5K episodes (20 eval points)
EVAL_EPISODES = 500        # more eval episodes for stable estimates

SNAPSHOT_DIR.mkdir(parents=True, exist_ok=True)

# ── Run 3 seeds ──────────────────────────────────────────────────────────
pooled_extended_results = {}

# Compute baselines once (500 eval episodes, deterministic seeds)
print("Computing baselines...")
pooled_random = run_rollouts(env, n_episodes=500, policy="random", seed=99)
pooled_no_promo = run_rollouts(env, n_episodes=500, policy="no_promo", seed=99)
print(f"  Random baseline: {pooled_random['rewards'].mean():.2f} ± {pooled_random['rewards'].std():.2f}")
print(f"  No-promo baseline: {pooled_no_promo['rewards'].mean():.2f} ± {pooled_no_promo['rewards'].std():.2f}")

for seed in POOLED_SEEDS:
    print(f"\n{'='*70}")
    print(f"  Pooled DQN — seed={seed}, {POOLED_N_EPISODES:,} episodes")
    print(f"{'='*70}")

    extended_cfg = dict(seed=seed, n_episodes=POOLED_N_EPISODES, lr=3e-4,
                        eps_decay_steps=50_000, hidden=128, per_beta_steps=200_000,
                        eval_interval=EVAL_INTERVAL, eval_episodes=EVAL_EPISODES)
    cached = cache_load("pooled_extended", **extended_cfg)

    if cached is not None:
        pooled_extended_results[seed] = cached
        print(f"  Final eval: {cached['final_reward']:.2f} ± {cached['final_std']:.2f}")
        print(f"  Best eval:  {cached['best_eval']:.2f} at episode {cached['best_eval_ep']}")
        print(f"  Total steps: {cached['total_steps']:,}")
        continue

    # Fresh agent for each seed
    pooled_agent = DQNAgent(
        obs_dim=obs_dim, n_actions=n_actions,
        lr=3e-4, gamma=0.99,
        buffer_size=100_000, batch_size=128,
        target_update_freq=500,
        eps_start=1.0, eps_end=0.05,
        eps_decay_steps=50_000,  # longer exploration for 50K episodes
        hidden=128,
        per_beta_steps=200_000,  # anneal PER beta over more steps
        obs_scale=obs_scale,
    )

    py_random.seed(seed)
    torch.manual_seed(seed)
    np.random.seed(seed)

    pooled_trainer = Trainer(
        env, pooled_agent, seed=seed,
        snapshot_dir=SNAPSHOT_DIR, label="pooled",
    )
    metrics = pooled_trainer.train(
        n_episodes=POOLED_N_EPISODES,
        eval_interval=EVAL_INTERVAL,
        eval_episodes=EVAL_EPISODES,
        snapshot_interval=SNAPSHOT_INTERVAL,
    )

    # Final greedy evaluation
    greedy_fn = lambda obs, _a=pooled_agent: _a.select_action(obs, greedy=True)
    final_eval = run_rollouts(env, n_episodes=500, policy=greedy_fn, seed=99)

    # Action distribution
    final_actions = np.bincount(final_eval["actions"], minlength=n_actions)
    final_action_freq = final_actions / final_actions.sum()
    n_unique = (final_action_freq > 0.01).sum()

    result = {
        "final_reward": final_eval["rewards"].mean(),
        "final_std": final_eval["rewards"].std(),
        "best_eval": metrics["eval_rewards"].max(),
        "best_eval_ep": int(metrics["eval_points"][metrics["eval_rewards"].argmax()]),
        "final_eval": metrics["eval_rewards"][-1],
        "total_steps": pooled_agent.step_count,
        "eval_curve": metrics["eval_rewards"].tolist(),
        "eval_points": metrics["eval_points"].tolist(),
        "n_unique_actions": int(n_unique),
        "top_action": int(final_action_freq.argmax()),
        "top_action_freq": float(final_action_freq.max()),
        "snapshots": metrics["snapshot_paths"],
    }

    pooled_extended_results[seed] = result
    cache_save(result, "pooled_extended", **extended_cfg)

    print(f"\n  Final eval: {final_eval['rewards'].mean():.2f} ± {final_eval['rewards'].std():.2f}")
    print(f"  Best eval:  {metrics['eval_rewards'].max():.2f} at episode {metrics['eval_points'][metrics['eval_rewards'].argmax()]}")
    print(f"  Total steps: {pooled_agent.step_count:,}")
    print(f"  Unique actions (>1%): {n_unique}")
    print(f"  Top action: {final_action_freq.argmax()} ({final_action_freq.max():.1%})")
    print(f"  Snapshots saved: {len(metrics['snapshot_paths'])}")

# ── Cross-seed summary ───────────────────────────────────────────────────
print(f"\n{'='*80}")
print(f"  Pooled DQN Extended Summary ({POOLED_N_EPISODES:,} episodes × {len(POOLED_SEEDS)} seeds)")
print(f"{'='*80}")

no_promo_mean = pooled_no_promo["rewards"].mean()
random_mean = pooled_random["rewards"].mean()

print(f"\nBaselines: No-promo={no_promo_mean:.2f}, Random={random_mean:.2f}")
print(f"\n{'Seed':>6} {'Final Eval':>12} {'Best Eval':>12} {'Best @ Ep':>10} "
      f"{'Steps':>10} {'DQN−NP':>10} {'Actions':>8}")
print("-" * 75)

final_rewards = []
for seed, res in pooled_extended_results.items():
    adv = res["final_reward"] - no_promo_mean
    final_rewards.append(res["final_reward"])
    print(f"{seed:>6} {res['final_reward']:>12.2f} {res['best_eval']:>12.2f} "
          f"{res['best_eval_ep']:>10,} {res['total_steps']:>10,} "
          f"{adv:>+10.2f} {res['n_unique_actions']:>8}")

final_rewards = np.array(final_rewards)
mean_r = final_rewards.mean()
se_r = final_rewards.std() / np.sqrt(len(final_rewards))
mean_adv = mean_r - no_promo_mean

print(f"\n  Mean final reward: {mean_r:.2f} ± {se_r:.2f}")
print(f"  Mean DQN−NP advantage: {mean_adv:+.2f}")
print(f"  {'→ DQN outperforms no-promo' if mean_adv > 0 else '→ DQN still net-neutral or worse'}")

# Save to JSON
pooled_summary = {
    "n_episodes": POOLED_N_EPISODES,
    "seeds": POOLED_SEEDS,
    "no_promo_baseline": float(no_promo_mean),
    "random_baseline": float(random_mean),
    "per_seed": {
        str(seed): {
            "final_reward": res["final_reward"],
            "final_std": res["final_std"],
            "best_eval": res["best_eval"],
            "best_eval_ep": res["best_eval_ep"],
            "total_steps": res["total_steps"],
            "eval_curve": res["eval_curve"],
            "eval_points": res["eval_points"],
            "n_unique_actions": res["n_unique_actions"],
        }
        for seed, res in pooled_extended_results.items()
    },
    "aggregate": {
        "mean_reward": float(mean_r),
        "se_reward": float(se_r),
        "mean_advantage_vs_no_promo": float(mean_adv),
    },
}

with open(SNAPSHOT_DIR / "pooled_extended_results.json", "w") as f:
    _json.dump(pooled_summary, f, indent=2)
print(f"\nResults saved to {SNAPSHOT_DIR / 'pooled_extended_results.json'}")

# %%
# ── Pooled DQN: Eval reward curves from saved checkpoints ─────────────────────
# The inline eval_curve data has a systematic offset; re-evaluate from snapshots.
import json, numpy as np, matplotlib.pyplot as plt
from pathlib import Path

SNAPSHOT_DIR = Path("../runs/overnight")
if not SNAPSHOT_DIR.exists():
    SNAPSHOT_DIR = Path("runs/overnight")

POOLED_SEEDS = [42, 123, 456]
EVAL_EPISODES = 200  # fewer than 500 for speed; still stable enough

# Load baselines from JSON
with open(SNAPSHOT_DIR / "pooled_extended_results.json") as f:
    pooled_json = json.load(f)

no_promo_base = pooled_json["no_promo_baseline"]
random_base = pooled_json["random_baseline"]

# Evaluate each checkpoint
seed_curves = {}
for seed in POOLED_SEEDS:
    snapshots = sorted(
        SNAPSHOT_DIR.glob(f"pooled_seed{seed}_ep*.pt"),
        key=lambda p: int(p.stem.split("_ep")[1]),  # sort by episode number, not string
    )
    eps_list, rewards_list = [], []
    for snap_path in snapshots:
        ep_num = int(snap_path.stem.split("_ep")[1])
        checkpoint = torch.load(snap_path, map_location=device, weights_only=False)

        # Build a fresh agent and load weights
        eval_agent = DQNAgent(
            obs_dim=obs_dim, n_actions=n_actions,
            lr=3e-4, gamma=0.99,
            buffer_size=1000, batch_size=128,
            target_update_freq=500,
            eps_start=0.0, eps_end=0.0, eps_decay_steps=1,  # fully greedy
            hidden=128, per_beta_steps=1,
            obs_scale=obs_scale,
        )
        eval_agent.q_net.load_state_dict(checkpoint["q_net"])
        eval_agent.q_net.eval()

        greedy_fn = lambda obs, _a=eval_agent: _a.select_action(obs, greedy=True)
        stats = run_rollouts(env, n_episodes=EVAL_EPISODES, policy=greedy_fn, seed=99)
        eps_list.append(ep_num / 1000)
        rewards_list.append(stats["rewards"].mean())

    seed_curves[seed] = (np.array(eps_list), np.array(rewards_list))
    print(f"Seed {seed}: {len(snapshots)} checkpoints evaluated, "
          f"range [{min(rewards_list):.2f}, {max(rewards_list):.2f}]")

# Plot
fig, ax = plt.subplots(figsize=(10, 5))
seed_colors = {42: "#2ca02c", 123: "#1f77b4", 456: "#ff7f0e"}

# Align all seeds to a common episode grid (they should match, but be safe)
common_eps = seed_curves[POOLED_SEEDS[0]][0]
aligned_rewards = []
for seed in POOLED_SEEDS:
    eps, rewards = seed_curves[seed]
    ax.plot(eps, rewards, color=seed_colors[seed], alpha=0.4, linewidth=1,
            label=f"Seed {seed}")
    aligned_rewards.append(rewards)

# Mean ± 1 SE band
aligned_rewards = np.array(aligned_rewards)
mean_curve = aligned_rewards.mean(axis=0)
se_curve = aligned_rewards.std(axis=0) / np.sqrt(len(aligned_rewards))

ax.plot(common_eps, mean_curve, color="black", linewidth=2, label="Mean (3 seeds)")
ax.fill_between(common_eps, mean_curve - se_curve, mean_curve + se_curve,
                color="black", alpha=0.15)

# Baselines (ordered top-to-bottom to match visual position on chart)
ax.axhline(random_base, color="#9467bd", linestyle="--", alpha=0.6,
           label=f"Random ({random_base:.2f})")
ax.axhline(no_promo_base, color="#d62728", linestyle="--", alpha=0.6,
           label=f"No-promo ({no_promo_base:.2f})")

ax.set_xlabel("Training episodes (thousands)", fontsize=11)
ax.set_ylabel("Eval reward (greedy, 200 episodes)", fontsize=11)
ax.set_title("Pooled DQN: Learning Curve from Checkpoints (3 seeds)",
             fontsize=13, fontweight="bold")
ax.legend(fontsize=8, loc="lower right")
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Seed 42: 16 checkpoints evaluated, range [27.46, 28.20]
# Seed 123: 16 checkpoints evaluated, range [27.57, 28.28]
# Seed 456: 16 checkpoints evaluated, range [27.77, 28.56]

# %% [markdown]
# ### 10.3 Pooled DQN: Action Distribution by Category
#
# Does the pooled agent's lift come primarily from ice cream promotions (the only
# category where per-category DQN beats the baseline), or does it spread actions
# across categories? We reload the best checkpoint and analyze the greedy policy.

# %%
# ── Pooled DQN: Action distribution by category ──────────────────────────
# Load best checkpoint (seed 456, ep 65K) and run greedy rollout

best_snap = SNAPSHOT_DIR / "pooled_seed456_ep65000.pt"
assert best_snap.exists(), f"Checkpoint not found: {best_snap}"

checkpoint = torch.load(best_snap, map_location=device, weights_only=False)
pooled_eval_agent = DQNAgent(
    obs_dim=obs_dim, n_actions=n_actions,
    lr=3e-4, gamma=0.99,
    buffer_size=1000, batch_size=128,
    target_update_freq=500,
    eps_start=0.0, eps_end=0.0, eps_decay_steps=1,
    hidden=128, per_beta_steps=1,
    obs_scale=obs_scale,
)
pooled_eval_agent.q_net.load_state_dict(checkpoint["q_net"])
pooled_eval_agent.q_net.eval()

greedy_fn = lambda obs, _a=pooled_eval_agent: _a.select_action(obs, greedy=True)
pooled_action_stats = run_rollouts(env, n_episodes=500, policy=greedy_fn, seed=99)

# Action counts
action_counts = np.bincount(pooled_action_stats["actions"], minlength=n_actions)
action_freq = action_counts / action_counts.sum()

# ── Color scheme (blue/gray, matching Phase 2) ───────────────────────────
#  Ice cream = blue (the only category with clear DQN lift)
#  Everything else = gray tones
CAT_COLORS = {
    "No Promo":    "#D4D4D4",
    "FLUID MILK":  "#A0A0A0",
    "ICE CREAM":   "#2E86AB",
    "FROZEN PIZZA": "#E8A838",
    "CANDY":       "#808080",
}

# Group by category
cat_names_ordered = list(CATEGORY_GROUPS.keys())
cat_labels = ["No Promo"] + cat_names_ordered
cat_freqs = [action_freq[0]]
cat_counts = [action_counts[0]]
for cat_name in cat_names_ordered:
    prod_indices = CATEGORY_GROUPS[cat_name]
    action_ids = [p + 1 for p in prod_indices]
    cat_freqs.append(action_freq[action_ids].sum())
    cat_counts.append(action_counts[action_ids].sum())

# ── Print summary ─────────────────────────────────────────────────────────
print("Pooled DQN (seed 456, ep 65K) — Greedy Action Distribution by Category")
print("=" * 45)
print(f"{'Category':<20} {'Frequency':>12}")
print("-" * 34)
for label, freq in zip(cat_labels, cat_freqs):
    print(f"{label:<20} {freq:>11.1%}")

# ── Visualization ─────────────────────────────────────────────────────────
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Left: per-action bar chart colored by category
cat_colors_map = {0: CAT_COLORS["No Promo"]}
for cat_name, prod_indices in CATEGORY_GROUPS.items():
    for p in prod_indices:
        cat_colors_map[p + 1] = CAT_COLORS[cat_name]

bar_colors = [cat_colors_map.get(a, "#A0A0A0") for a in range(n_actions)]
ax1.bar(range(n_actions), action_freq, color=bar_colors, edgecolor="black", linewidth=0.5)
ax1.set_xticks(range(n_actions))
action_labels_short = ["NP"] + [str(pid)[-4:] for pid in all_selected_ids]
ax1.set_xticklabels(action_labels_short, rotation=45, ha="right", fontsize=7)
ax1.set_ylabel("Frequency")
ax1.set_title("Per-Action Distribution (80K pooled DQN)")
ax1.axhline(1 / n_actions, color="red", linestyle=":", alpha=0.5, label="Uniform")
ax1.legend(fontsize=8)

# Right: category-level pie chart
cat_plot_colors = [CAT_COLORS[l] for l in cat_labels]
wedges, texts, autotexts = ax2.pie(
    cat_freqs, labels=cat_labels, colors=cat_plot_colors,
    autopct=lambda pct: f"{pct:.1f}%" if pct > 2 else "",
    startangle=90, textprops={"fontsize": 9},
)
ax2.set_title("Action Share by Category (80K pooled DQN)")

plt.tight_layout()
plt.show()

# ── Policy heatmaps: greedy action vs (churn, category memory) ────────────
# Two panels: raise ALL Ice Cream products' memory vs ALL Frozen Pizza
# products' memory. This tests whether saturating an entire category's
# memory causes the agent to switch to a different category.

def _make_obs(churn, memory_vals=None, recency_vals=None):
    n = env.N
    mem = np.zeros(n) if memory_vals is None else np.array(memory_vals)
    rec = np.full(n, env.recency_sentinel) if recency_vals is None else np.array(recency_vals)
    return np.concatenate([[churn], mem, rec]).astype(np.float32)

def _get_greedy_action(obs):
    with torch.no_grad():
        normed = torch.FloatTensor(obs).unsqueeze(0).to(device) / pooled_eval_agent.obs_scale
        q = pooled_eval_agent.q_net(normed).squeeze(0).cpu().numpy()
    return int(q.argmax())

def _action_to_cat(a):
    if a == 0:
        return "No Promo"
    pid_idx = a - 1
    for cat_name, prod_indices in CATEGORY_GROUPS.items():
        if pid_idx in prod_indices:
            return cat_name
    return "Unknown"

# Category index map for coloring
cat_to_idx = {label: i for i, label in enumerate(cat_labels)}
all_cat_colors = [CAT_COLORS[l] for l in cat_labels]

from matplotlib.colors import ListedColormap, BoundaryNorm
cmap = ListedColormap(all_cat_colors)
bounds = np.arange(-0.5, len(all_cat_colors) + 0.5, 1)
norm = BoundaryNorm(bounds, cmap.N)

# Sweep grids
churn_grid = np.linspace(0.01, 0.50, 40)
memory_grid = np.linspace(0, 6.0, 40)  # sweep to memory cap

ice_cream_indices = CATEGORY_GROUPS["ICE CREAM"]
frozen_pizza_indices = CATEGORY_GROUPS["FROZEN PIZZA"]

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

for ax, sweep_indices, cat_label in [
    (ax1, ice_cream_indices, "Ice Cream"),
    (ax2, frozen_pizza_indices, "Frozen Pizza"),
]:
    grid = np.zeros((len(memory_grid), len(churn_grid)), dtype=int)
    for mi, mem in enumerate(memory_grid):
        for ci, ch in enumerate(churn_grid):
            mem_vals = np.zeros(env.N)
            for idx in sweep_indices:
                mem_vals[idx] = mem
            obs = _make_obs(churn=ch, memory_vals=mem_vals, recency_vals=np.full(env.N, 5.0))
            a = _get_greedy_action(obs)
            grid[mi, ci] = cat_to_idx[_action_to_cat(a)]

    ax.imshow(grid, origin="lower", aspect="auto", cmap=cmap, norm=norm,
              extent=[churn_grid[0], churn_grid[-1], memory_grid[0], memory_grid[-1]])
    ax.set_xlabel("Churn propensity")
    ax.set_ylabel(f"All {cat_label} products' memory")
    ax.set_title(f"Greedy action: Churn × {cat_label} Memory")

# Shared legend
from matplotlib.patches import Patch
legend_patches = [Patch(facecolor=CAT_COLORS[l], edgecolor="black", label=l)
                  for l in cat_labels]
fig.legend(handles=legend_patches, loc="lower center", ncol=len(cat_labels),
           fontsize=9, frameon=True, bbox_to_anchor=(0.5, -0.02))

fig.suptitle("Pooled DQN: Greedy Action as Category-Level Memory Increases",
             fontsize=13, fontweight="bold")
plt.tight_layout(rect=[0, 0.05, 1, 0.95])
plt.show()

# ── Comparison to per-category results ────────────────────────────────────
print(f"\nKey question: Is the pooled DQN's ~4.5% lift driven by ice cream?")
ice_cream_share = cat_freqs[cat_labels.index("ICE CREAM")]
print(f"  Ice cream action share: {ice_cream_share:.1%}")
print(f"  If uniform across 5 categories (inc. no-promo): {1/5:.1%}")
print(f"  Ice cream is {'over' if ice_cream_share > 0.25 else 'under'}represented "
      f"({ice_cream_share / 0.2:.1f}× vs uniform)")
# Out:
# Pooled DQN (seed 456, ep 65K) — Greedy Action Distribution by Category
# =============================================
# Category                Frequency
# ----------------------------------
# No Promo                    0.9%
# FLUID MILK                  9.4%
# ICE CREAM                  51.3%
# FROZEN PIZZA               30.7%
# CANDY                       7.8%
# Key question: Is the pooled DQN's ~4.5% lift driven by ice cream?
#   Ice cream action share: 51.3%
#   If uniform across 5 categories (inc. no-promo): 20.0%
#   Ice cream is overrepresented (2.6× vs uniform)

# %%
# ── On-policy heatmap: category memory vs churn, 2x2 grid ──
# Collect (state, action) from 500 greedy rollout episodes, then bin by
# each category's mean product memory (x-axis) vs churn (y-axis).

# Collect on-policy states and actions
on_policy_states = []
on_policy_actions = []

greedy_fn = lambda obs, _a=pooled_eval_agent: _a.select_action(obs, greedy=True)

for ep in range(500):
    obs, _ = env.reset(seed=99 + ep)
    done = False
    while not done:
        a = greedy_fn(obs)
        on_policy_states.append(obs.copy())
        on_policy_actions.append(a)
        obs, _, terminated, truncated, _ = env.step(a)
        done = terminated or truncated

on_policy_states = np.array(on_policy_states)
on_policy_actions = np.array(on_policy_actions)

# Map actions to category indices
action_cats = np.array([cat_to_idx[_action_to_cat(a)] for a in on_policy_actions])

# Extract churn (obs[0]) for all steps
churn_vals = on_policy_states[:, 0]

from scipy.stats import mode as scipy_mode

categories = ["ICE CREAM", "FROZEN PIZZA", "FLUID MILK", "CANDY"]
n_bins = 20

fig, axes = plt.subplots(2, 2, figsize=(12, 10))

for ax, cat_name in zip(axes.flat, categories):
    cat_indices = CATEGORY_GROUPS[cat_name]
    cat_mem = on_policy_states[:, [1 + i for i in cat_indices]].mean(axis=1)

    mem_bins = np.linspace(cat_mem.min(), cat_mem.max() + 1e-6, n_bins + 1)
    churn_bins = np.linspace(churn_vals.min(), churn_vals.max() + 1e-6, n_bins + 1)

    mem_bin_idx = np.digitize(cat_mem, mem_bins) - 1
    churn_bin_idx = np.digitize(churn_vals, churn_bins) - 1

    grid_mode = np.full((n_bins, n_bins), np.nan)
    for i in range(n_bins):
        for j in range(n_bins):
            mask = (mem_bin_idx == i) & (churn_bin_idx == j)
            if mask.sum() >= 3:
                grid_mode[j, i] = scipy_mode(action_cats[mask], keepdims=False).mode

    masked_grid = np.ma.masked_invalid(grid_mode)
    ax.imshow(masked_grid, origin="lower", aspect="auto", cmap=cmap, norm=norm,
              extent=[mem_bins[0], mem_bins[-1], churn_bins[0], churn_bins[-1]])
    ax.set_xlabel(f"{cat_name.title()} mean memory")
    ax.set_ylabel("Churn propensity")
    ax.set_title(cat_name.title(), fontsize=12, fontweight="bold")

from matplotlib.patches import Patch
legend_patches = [Patch(facecolor=CAT_COLORS[l], edgecolor="black", label=l)
                  for l in cat_labels]
fig.legend(handles=legend_patches, loc="lower center", ncol=len(cat_labels) + 1,
           fontsize=10, frameon=True, bbox_to_anchor=(0.5, -0.01))
fig.suptitle("Pooled DQN: Greedy Action by Category Memory vs Churn\n(on-policy states, 500 episodes)",
             fontsize=14, fontweight="bold")
plt.tight_layout(rect=[0, 0.04, 1, 0.93])
plt.savefig("on_policy_heatmap.png", dpi=150, bbox_inches="tight")
plt.show()

# Print memory ranges actually visited
print("On-policy memory ranges:")
for cat_name in categories:
    cat_indices = CATEGORY_GROUPS[cat_name]
    cat_mem = on_policy_states[:, [1 + i for i in cat_indices]].mean(axis=1)
    print(f"  {cat_name:>14s}: [{cat_mem.min():.3f}, {cat_mem.max():.3f}]")
print(f"  {'Churn':>14s}: [{churn_vals.min():.3f}, {churn_vals.max():.3f}]")
print(f"Total state-action pairs: {len(on_policy_actions):,}")
# Out:
# On-policy memory ranges:
#        ICE CREAM: [0.000, 2.947]
#     FROZEN PIZZA: [0.000, 1.872]
#       FLUID MILK: [0.000, 1.291]
#            CANDY: [0.000, 1.306]
#            Churn: [0.050, 0.327]
# Total state-action pairs: 7,633

# %%
# ── Time-series of a single greedy episode ──
# Show which product the agent promotes at each step, colored by category,
# alongside the memory of the promoted product to see rotation patterns.

TOP_PROD_IDX = 9  # product 1118033

# Run one long episode
obs, _ = env.reset(seed=42)
episode_actions = []
episode_memories = []  # memory of ALL products at each step
done = False
while not done:
    a = _get_greedy_action(obs)
    mems = obs[1:1+env.N].copy()  # raw memory values for all products
    episode_actions.append(a)
    episode_memories.append(mems)
    obs, _, terminated, truncated, _ = env.step(a)
    done = terminated or truncated

T = len(episode_actions)
print(f"Episode length: {T} steps")

# Classify actions
cats = [_action_to_cat(a) for a in episode_actions]
cat_list = ["FLUID MILK", "ICE CREAM", "FROZEN PIZZA", "CANDY"]
cat_y = {"No Promo": 0, "FLUID MILK": 1, "ICE CREAM": 2, "FROZEN PIZZA": 3, "CANDY": 4}
CAT_COLORS_TS = {
    "No Promo": "#D4D4D4", "FLUID MILK": "#A0A0A0",
    "ICE CREAM": "#2E86AB", "FROZEN PIZZA": "#E8A838", "CANDY": "#808080",
}

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 7), sharex=True,
                                 gridspec_kw={"hspace": 0.12, "height_ratios": [2, 1.5]})

# Top: action timeline as colored scatter
steps = np.arange(T)
for step in range(T):
    c = cats[step]
    ax1.scatter(step, cat_y[c], color=CAT_COLORS_TS[c], s=12, zorder=2)

ax1.set_yticks(list(cat_y.values()))
ax1.set_yticklabels(list(cat_y.keys()), fontsize=10)
ax1.set_ylabel("Action Category", fontsize=11)
ax1.set_title("Single Greedy Episode: Product Promotion Over Time",
              fontsize=13, fontweight="bold")
ax1.set_ylim(-0.5, 4.5)
ax1.grid(axis="x", alpha=0.3)

# Bottom: memory of the top 3 IC products over time
ic_indices = CATEGORY_GROUPS["ICE CREAM"]
ic_colors = ["#1B6B93", "#4BA3C7", "#7BC8E8", "#A8DCF0", "#D0EEF8"]
mem_array = np.array(episode_memories)  # shape (T, N)

for i, idx in enumerate(ic_indices):
    pid = all_selected_ids[idx]
    label = f"IC {pid}" + (" *" if idx == TOP_PROD_IDX else "")
    ax2.plot(steps, mem_array[:, idx], color=ic_colors[i], linewidth=1.2,
             alpha=0.8, label=label)

ax2.set_xlabel("Step", fontsize=11)
ax2.set_ylabel("Product Memory", fontsize=11)
ax2.legend(fontsize=8, ncol=5, loc="upper right", frameon=True)
ax2.grid(axis="both", alpha=0.3)

plt.tight_layout()
plt.show()

# Summary: how many unique products promoted, category breakdown
from collections import Counter
cat_counts = Counter(cats)
print("\nCategory breakdown:")
for c in ["ICE CREAM", "FROZEN PIZZA", "FLUID MILK", "CANDY", "No Promo"]:
    if c in cat_counts:
        print(f"  {c:>14s}: {cat_counts[c]:>4d} steps ({100*cat_counts[c]/T:.1f}%)")
print(f"\nUnique actions used: {len(set(episode_actions))}")
# Out:
# Episode length: 10 steps
# /var/folders/gf/550wq28x3b12kj3pv8149_tr0000gn/T/ipykernel_62796/564322977.py:65: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# Category breakdown:
#        ICE CREAM:   10 steps (100.0%)
#
# Unique actions used: 1
