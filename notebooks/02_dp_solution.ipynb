# %% [markdown]
# # Dynamic Programming Solution
#
# Phase 2: Solving the discount pricing MDP using Dynamic Programming.

# %%
import numpy as np
from discount_engine.agents.dp_agent import DPAgent
from discount_engine.envs.market_env import MarketEnv
